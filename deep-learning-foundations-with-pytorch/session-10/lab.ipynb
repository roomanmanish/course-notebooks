# %% [markdown]
# Build and train a neural network regressor on a realistic dataset and compare its predictions and errors against a classical ML regression baseline.

# %%
# Write your solution here
