# %% [markdown]
# Independently prepare data, build a baseline neural network, diagnose training behavior, iteratively improve the model, and perform error analysis on a realistic dataset.

# %%
# Write your solution here
