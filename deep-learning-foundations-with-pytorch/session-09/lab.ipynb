# %% [markdown]
# # Building a Multiclass Classifier
#
# ## Problem
# You have a dataset of flower measurements in `data.csv` with 4 numeric features and a `species` label with 3 possible classes (0, 1, 2).
#
# Your task: build a neural network with a softmax-style output layer, train it with cross-entropy loss, and evaluate it on held-out data using a confusion matrix and precision/recall/F1 metrics.

# %% [markdown]
# ## Expected output
# - `X_train`/`X_test` are feature tensors, `y_train`/`y_test` contain only 0/1/2.
# - A test sample like `[5.0, 3.4, 1.5, 0.2]` should be classified as class 0; `[6.5, 3.0, 5.5, 1.8]` as class 2.
# - Training loss should decrease over epochs.
# - Final `metrics` should show high diagonal mass in the confusion matrix and accuracy clearly above chance (1/3).

# %%
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_fscore_support, accuracy_score

random.seed(42)
np.random.seed(42)
torch.manual_seed(42)

# %%
def load_data(path="data.csv", test_size=0.2, random_state=42):
    """Load the CSV at `path`, split into train/test sets, and return
    (X_train, X_test, y_train, y_test) as torch tensors.
    Features should be float tensors, labels should be long tensors.
    """
    raise NotImplementedError

# %%
class MultiClassClassifier(nn.Module):
    """A neural network that maps `input_dim` numeric features to
    `num_classes` output scores (logits) suitable for cross-entropy loss.
    """
    def __init__(self, input_dim, num_classes, hidden_dim=16):
        super().__init__()
        raise NotImplementedError

    def forward(self, x):
        raise NotImplementedError

# %%
def train_model(model, X_train, y_train, epochs=200, lr=0.05):
    """Train `model` on (X_train, y_train) using cross-entropy loss.
    Return (model, losses) where `losses` is a list with one loss value
    per epoch, in order.
    """
    raise NotImplementedError

# %%
def evaluate_model(model, X_test, y_test):
    """Generate predictions for X_test using `model` and compare against
    y_test. Return (y_pred, y_true, metrics) where y_pred/y_true are
    1-D numpy arrays of class labels, and `metrics` is a dict with keys
    'accuracy', 'confusion_matrix', 'precision', 'recall', 'f1'.
    """
    raise NotImplementedError

# %% [markdown]
# ## Run your pipeline
# Use the functions/classes above to load the data, build and train the model, and evaluate it. Fill in the bodies above first, then run the cells below.

# %%
X_train, X_test, y_train, y_test = load_data()
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)

# %%
model = MultiClassClassifier(input_dim=X_train.shape[1], num_classes=3)
model

# %%
model, losses = train_model(model, X_train, y_train)
print("first loss:", losses[0], "last loss:", losses[-1])

# %%
plt.plot(losses)
plt.xlabel("epoch")
plt.ylabel("loss")
plt.title("Training loss")
plt.show()

# %%
y_pred, y_true, metrics = evaluate_model(model, X_test, y_test)
print("accuracy:", metrics["accuracy"])
print("confusion_matrix:")
print(metrics["confusion_matrix"])
print("precision:", metrics["precision"], "recall:", metrics["recall"], "f1:", metrics["f1"])

# %% [markdown]
# ## Reflect
# Looking at your confusion matrix: which class(es) does the model confuse most? Would collecting more data, changing the network size, or training longer help? (No submission needed for this cell -- just think it through.)
