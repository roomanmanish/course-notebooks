# %% [markdown]
# # Clean and Analyze a Real Dataset with Pandas
#
# ## Your Mission
#
# Imagine you work at an e-commerce company. Your sales team has collected order data from the past quarter, but it's a mess:
# - Some orders are duplicated (entered twice by mistake).
# - Some fields are missing (a customer forgot to enter the quantity, or the price wasn't recorded).
# - The data is scattered across different regions, and you need to summarize it by region and product category.
#
# Your job: **clean this data and answer key business questions** like:
# - Which region generated the most revenue?
# - What is the average order value by product category?
# - How many orders did each customer place?
#
# Let's start by loading and exploring the data.

# %% [markdown]
# ## Step 1: Load and Explore the Data
#
# First, load the CSV file and take a look at what we're working with. Use Pandas to read the file and inspect its structure.

# %%
import pandas as pd
import numpy as np

# Load the CSV file
df = pd.read_csv('data.csv')

# Display the first few rows
print("First few rows:")
print(df.head())

# Check the shape and data types
print("\nDataFrame info:")
print(df.info())

# Check for missing values
print("\nMissing values:")
print(df.isnull().sum())

# %% [markdown]
# ## Step 2: Clean the Data
#
# Now it's your turn. Write a function called `clean_sales` that:
# - Removes duplicate rows (keep only the first occurrence).
# - Handles missing values in the `quantity` column by filling with the median quantity for that product category.
# - Handles missing values in the `unit_price` column by filling with the median price for that product category.
# - Removes any rows where critical fields (like `order_id`, `customer_id`, `region`) are still missing after filling.
# - Returns the cleaned DataFrame.
#
# The cleaned DataFrame should have **no duplicate rows** and **no missing values** in any column.

# %%
def clean_sales(df):
    """
    Clean the sales DataFrame by removing duplicates and handling missing values.
    
    Parameters:
    df (pd.DataFrame): Raw sales data
    
    Returns:
    pd.DataFrame: Cleaned sales data with no duplicates and no missing values
    """
    pass

# Test your function
df_clean = clean_sales(df)
print("Cleaned DataFrame:")
print(df_clean.head())
print(f"\nShape: {df_clean.shape}")
print(f"Missing values: {df_clean.isnull().sum().sum()}")

# %% [markdown]
# ## Step 3: Filter the Data
#
# Write a function called `filter_high_value_orders` that:
# - Takes the cleaned DataFrame and a minimum quantity threshold.
# - Returns only the rows where `quantity` is greater than or equal to the threshold.
#
# For example, if the threshold is 5, you should get all orders with 5 or more items.

# %%
def filter_high_value_orders(df, min_quantity):
    """
    Filter orders by minimum quantity.
    
    Parameters:
    df (pd.DataFrame): Cleaned sales data
    min_quantity (int): Minimum quantity threshold
    
    Returns:
    pd.DataFrame: Filtered DataFrame with only orders meeting the threshold
    """
    pass

# Test your function
high_value = filter_high_value_orders(df_clean, 5)
print(f"Orders with quantity >= 5:")
print(high_value)

# %% [markdown]
# ## Step 4: Aggregate Data by Region
#
# Write a function called `revenue_by_region` that:
# - Takes the cleaned DataFrame.
# - Calculates the total revenue for each order (quantity × unit_price).
# - Groups by region and sums the revenue.
# - Returns a Series with region as the index and total revenue as the values, sorted in descending order by revenue.
#
# This tells us which regions are generating the most sales.

# %%
def revenue_by_region(df):
    """
    Calculate total revenue grouped by region.
    
    Parameters:
    df (pd.DataFrame): Cleaned sales data
    
    Returns:
    pd.Series: Total revenue by region, sorted descending
    """
    pass

# Test your function
revenue_region = revenue_by_region(df_clean)
print("Total revenue by region:")
print(revenue_region)

# %% [markdown]
# ## Step 5: Aggregate Data by Product Category
#
# Write a function called `avg_order_value_by_category` that:
# - Takes the cleaned DataFrame.
# - Calculates the order value for each row (quantity × unit_price).
# - Groups by product category and computes the average order value.
# - Returns a Series with product category as the index and average order value as the values, sorted in descending order.
#
# This shows which product categories have the highest average order values.

# %%
def avg_order_value_by_category(df):
    """
    Calculate average order value grouped by product category.
    
    Parameters:
    df (pd.DataFrame): Cleaned sales data
    
    Returns:
    pd.Series: Average order value by category, sorted descending
    """
    pass

# Test your function
avg_by_category = avg_order_value_by_category(df_clean)
print("Average order value by product category:")
print(avg_by_category)

# %% [markdown]
# ## Step 6: Customer Purchase Frequency
#
# Write a function called `orders_per_customer` that:
# - Takes the cleaned DataFrame.
# - Groups by customer_id and counts the number of orders per customer.
# - Returns a Series with customer_id as the index and order count as the values, sorted in descending order by count.
#
# This helps identify your most active customers.

# %%
def orders_per_customer(df):
    """
    Count the number of orders per customer.
    
    Parameters:
    df (pd.DataFrame): Cleaned sales data
    
    Returns:
    pd.Series: Number of orders per customer, sorted descending
    """
    pass

# Test your function
customer_orders = orders_per_customer(df_clean)
print("Orders per customer:")
print(customer_orders)

# %% [markdown]
# ## Summary
#
# Congratulations! You've successfully:
# 1. Loaded and explored a real-world messy dataset.
# 2. Cleaned the data by removing duplicates and handling missing values intelligently.
# 3. Filtered data to find high-value orders.
# 4. Aggregated data to answer business questions about revenue, product performance, and customer behavior.
#
# These are the core skills of a data analyst. In the real world, you'd use these insights to make decisions like:
# - Investing more in high-revenue regions.
# - Promoting high-value product categories.
# - Rewarding loyal, frequent customers.
#
# Great work!
