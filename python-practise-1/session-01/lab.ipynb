# %% [markdown]
# # Student Grade Calculator
#
# ## Problem
#
# Build a program that:
# 1. Reads student names and marks from a CSV file.
# 2. Converts marks to letter grades (A, B, C, D, F).
# 3. Determines if each student passed or failed.
# 4. Outputs a formatted report.
#
# ## Grading Rules
#
# - **A**: 90–100
# - **B**: 80–89
# - **C**: 70–79
# - **D**: 60–69
# - **F**: Below 60
#
# **Pass**: Grade D or above
# **Fail**: Grade F
#
# ## Expected Output Format
#
# ```
# Name: marks → Grade X → STATUS
# ```
#
# Example:
# ```
# Alice: 85 → Grade B → PASSED
# Bob: 55 → Grade F → FAILED
# ```

# %%
import pandas as pd

# Load the student data
students_df = pd.read_csv('students.csv')
print(students_df)

# %% [markdown]
# ## Step 1: Convert Marks to Letter Grade
#
# Write a function that takes a mark (0–100) and returns the corresponding letter grade.

# %%
def get_grade(marks):
    """
    Convert marks (0-100) to letter grade (A, B, C, D, F).
    
    Args:
        marks: Integer between 0 and 100
    
    Returns:
        String: 'A', 'B', 'C', 'D', or 'F'
    """
    pass

# %% [markdown]
# ## Step 2: Determine Pass/Fail Status
#
# Write a function that takes a letter grade and returns 'PASSED' or 'FAILED'.

# %%
def get_status(grade):
    """
    Determine if a student passed or failed based on their grade.
    
    Args:
        grade: String ('A', 'B', 'C', 'D', or 'F')
    
    Returns:
        String: 'PASSED' or 'FAILED'
    """
    pass

# %% [markdown]
# ## Step 3: Generate the Report
#
# Process all students and print the formatted report.

# %%
def generate_report(df):
    """
    Generate a formatted grade report for all students.
    
    Args:
        df: DataFrame with columns 'name' and 'marks'
    
    Returns:
        None (prints the report)
    """
    pass

# %% [markdown]
# ## Run the Report
#
# Call the function to generate and display the report.

# %%
generate_report(students_df)
