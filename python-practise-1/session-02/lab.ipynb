# %% [markdown]
# # Sales Data Analysis Lab
#
# In this lab, you will load a real-world sales dataset, clean it, and generate business insights.
#
# ## The Story
#
# Imagine you work at a retail company. Your manager hands you a spreadsheet with sales data from the past year. The data looks like this:
#
# | Date | Product | Category | Region | Quantity | Price | Revenue |
# |------|---------|----------|--------|----------|-------|---------|
# | 2024-01-01 | Laptop | Electronics | North | 2 | 800 | 1600 |
# | 2024-01-02 | Shirt | Clothing | South | -1 | 20 | (missing) |
# | 2024-01-03 | Sofa | Home | East | 1 | 500 | 500 |
#
# Notice the problems:
# - Row 2 has a **negative quantity** (invalid)
# - Row 2 has a **missing revenue** value
#
# Your job: clean this data, answer business questions, and create a report your manager can act on.
#
# ## What You'll Learn
#
# - Load CSV data into Pandas
# - Inspect data quality (missing values, data types, shape)
# - Clean data by removing invalid rows
# - Filter data by conditions (region, date range)
# - Group and aggregate data to find patterns
# - Export results for decision-making

# %% [markdown]
# ## Step 1: Load and Inspect the Data
#
# Load the sales data from `sales_data.csv` and explore its structure. You should:
# - Display the shape (number of rows and columns)
# - Show the first few rows
# - Check data types
# - Identify missing values
# - Display basic statistics

# %%
import pandas as pd
import numpy as np

# Load the CSV file
df = pd.read_csv('sales_data.csv')

# TODO: Inspect the data
# Display shape
print(f'Shape: {df.shape}')

# Display first few rows
print('\nFirst few rows:')
print(df.head())

# Display data types
print('\nData types:')
print(df.dtypes)

# Display missing values
print('\nMissing values:')
print(df.isnull().sum())

# Display basic statistics
print('\nBasic statistics:')
print(df.describe())

# %% [markdown]
# ## Step 2: Clean the Data
#
# Create a cleaned dataset by:
# - Removing rows with missing values in critical columns (revenue, region, product_category)
# - Removing rows with invalid quantities (negative or zero)
# - Store the result in a variable called `cleaned_data`

# %%
# Clean the data
cleaned_data = None

# TODO: Remove rows with missing critical values
# TODO: Remove rows with invalid quantities
# TODO: Store result in cleaned_data

print(f'Original rows: {len(df)}')
print(f'Cleaned rows: {len(cleaned_data)}')
print(f'Rows removed: {len(df) - len(cleaned_data)}')

# Verify no missing values in critical columns
print('\nMissing values in cleaned data:')
print(cleaned_data[['revenue', 'region', 'product_category']].isnull().sum())

# %% [markdown]
# ## Step 3: Filter Data by Region
#
# Filter the cleaned data to include only transactions from specific regions (e.g., 'North' and 'East'). Store the result in a variable called `regional_data`.

# %%
# Filter data by region
regional_data = None

# TODO: Filter cleaned_data for regions 'North' and 'East'
# TODO: Store result in regional_data

print(f'Rows in regional data: {len(regional_data)}')
print('\nRegions in filtered data:')
print(regional_data['region'].unique())
print('\nFirst few rows of regional data:')
print(regional_data.head())

# %% [markdown]
# ## Step 4: Calculate Revenue by Product Category
#
# Group the cleaned data by product category and calculate:
# - Total revenue per category
# - Number of transactions per category
#
# Sort by total revenue in descending order. Store the result in a variable called `category_summary`.

# %%
# Calculate revenue by product category
category_summary = None

# TODO: Group cleaned_data by product_category
# TODO: Calculate total revenue and transaction count
# TODO: Sort by total revenue in descending order
# TODO: Store result in category_summary

print('Category Summary:')
print(category_summary)

# %% [markdown]
# ## Step 5: Identify Top Products
#
# Find the top 5 products by total revenue. Create a summary showing product name and total revenue. Store the result in a variable called `top_products`.

# %%
# Identify top products
top_products = None

# TODO: Group cleaned_data by product name
# TODO: Calculate total revenue per product
# TODO: Sort by revenue in descending order
# TODO: Select top 5 products
# TODO: Store result in top_products

print('Top 5 Products by Revenue:')
print(top_products)

# %% [markdown]
# ## Step 6: Export Results (Optional)
#
# Export the cleaned data and summary reports as CSV files for your manager.

# %%
# Optional: Export results
# cleaned_data.to_csv('cleaned_sales_data.csv', index=False)
# category_summary.to_csv('category_summary.csv', index=False)
# top_products.to_csv('top_products.csv', index=False)

print('Results ready for export!')

# %% [markdown]
# ## Summary
#
# You have successfully:
# 1. Loaded and inspected the sales data
# 2. Cleaned the data by removing invalid rows
# 3. Filtered data by region
# 4. Calculated revenue by product category
# 5. Identified top-performing products
#
# These insights can now be used by your manager to make decisions about inventory, marketing, and regional strategy.
