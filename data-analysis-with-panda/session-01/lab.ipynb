# %% [markdown]
# # Load and Explore a Sales Dataset
#
# In this lab, you will load a CSV sales dataset into Pandas and explore its structure, data types, and missing values.
#
# ## Instructions
#
# Complete each cell below by replacing `# TODO` comments with the appropriate Pandas code. Run each cell to verify your work.

# %% [markdown]
# ### Step 1: Import Pandas and Load the CSV File
#
# Load the file `data.csv` into a DataFrame named `df`.

# %%
import pandas as pd

# TODO: Load the CSV file 'data.csv' into a DataFrame named 'df'
df = None

# %% [markdown]
# ### Step 2: Display the Shape of the DataFrame
#
# Print the shape (number of rows and columns) of the DataFrame.

# %%
# TODO: Display the shape of the DataFrame
shape_result = None

# %% [markdown]
# ### Step 3: Display the First 5 Rows
#
# Use the `head()` method to view the first 5 rows.

# %%
# TODO: Display the first 5 rows using head()
head_result = None

# %% [markdown]
# ### Step 4: Display the Last 3 Rows
#
# Use the `tail()` method to view the last 3 rows.

# %%
# TODO: Display the last 3 rows using tail(3)
tail_result = None

# %% [markdown]
# ### Step 5: Display Data Types
#
# Use the `dtypes` attribute to see the data type of each column.

# %%
# TODO: Display the data types of all columns
dtypes_result = None

# %% [markdown]
# ### Step 6: Count Missing Values
#
# Use `isnull().sum()` to count missing values in each column.

# %%
# TODO: Count missing values in each column
missing_by_column = None

# %% [markdown]
# ### Step 7: Display Summary Statistics
#
# Use the `describe()` method to get summary statistics for numeric columns.

# %%
# TODO: Display summary statistics using describe()
summary_stats = None

# %% [markdown]
# ### Step 8: Access a Specific Column
#
# Access the 'Quantity' column and store it in a variable.

# %%
# TODO: Access the 'Quantity' column
quantity_column = None

# %% [markdown]
# ### Step 9: Access the First Row by Position
#
# Use `iloc[0]` to access the first row of the DataFrame.

# %%
# TODO: Access the first row using iloc[0]
first_row = None

# %% [markdown]
# ### Step 10: Calculate Total Missing Values
#
# Create a variable `missing_values_total` that holds the total count of NaN values in the entire DataFrame.

# %%
# TODO: Calculate the total number of missing values in the DataFrame
missing_values_total = None

# %% [markdown]
# ## Summary
#
# You have successfully:
# - Loaded a CSV file into a Pandas DataFrame
# - Inspected its shape, columns, and data types
# - Identified missing values
# - Viewed summary statistics
# - Navigated the DataFrame using indexing
#
# These are fundamental skills for data exploration and preparation!
