# %% [markdown]
# Load a messy real-world dataset, clean missing values and duplicates, standardize formats, perform exploratory analysis (groupby, pivot, merge), and generate a summary report with key insights.

# %%
# Write your solution here
