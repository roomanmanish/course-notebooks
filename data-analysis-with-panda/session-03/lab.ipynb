# %% [markdown]
# Group sales data by region and product category, create a pivot table showing revenue by region/category, and merge with a customer demographics table to analyze spending patterns.

# %%
# Write your solution here
