# %% [markdown]
# # Student Records Processor with Error Handling
#
# ## Problem
#
# You are building a **Student Records Processor** for a school. The system receives student data from a text file where each line contains a student's name, age, and three test scores. Your job is to:
#
# 1. **Read** the student records from a file called `students.txt`
# 2. **Validate** each record: check that all fields are present and that scores are valid numbers between 0 and 100
# 3. **Handle errors gracefully**: if a record is invalid, skip it and record what went wrong
# 4. **Calculate statistics**: for all valid records, compute the class average score and count how many students passed (score ≥ 60)
# 5. **Write a summary report** to a file called `report.txt` that includes:
#    - Total valid students processed
#    - Total invalid records skipped (with reasons)
#    - Class average score (rounded to 2 decimal places)
#    - Number of students who passed
#
# Your code must use **try-except-finally blocks** to handle file operations safely and validate data robustly. Use a **context manager** (`with` statement) to ensure files are closed properly.

# %% [markdown]
# ## Expected Output
#
# ### Example 1: Valid Input
#
# **Input file `students.txt`:**
# ```
# Alice,25,85,90,88
# Bob,24,72,68,75
# Charlie,23,95,92,98
# ```
#
# **Output file `report.txt`:**
# ```
# === Student Records Summary ===
# Total valid students: 3
# Total invalid records: 0
# Class average score: 84.67
# Students passed (score >= 60): 3
# ```
#
# ### Example 2: Mixed Valid and Invalid Records
#
# **Input file `students.txt`:**
# ```
# Alice,25,85,90,88
# Bob,24,72,invalid,75
# Charlie,23,95,92,98
# Diana,26
# Eve,22,55,60,58
# ```
#
# **Output file `report.txt`:**
# ```
# === Student Records Summary ===
# Total valid students: 3
# Total invalid records: 2
# Class average score: 79.33
# Students passed (score >= 60): 2
# ```
#
# ### Example 3: All Invalid Records
#
# **Input file `students.txt`:**
# ```
# Alice,25,85,150,88
# Bob,24,72,68
# ```
#
# **Output file `report.txt`:**
# ```
# === Student Records Summary ===
# Total valid students: 0
# Total invalid records: 2
# Class average score: 0.00
# Students passed (score >= 60): 0
# ```

# %% [markdown]
# ## Implementation
#
# Complete the function below to process student records and generate a summary report.

# %%
def process_student_records(input_file):
    """
    Read student records from a file, validate them, calculate statistics,
    and write a summary report.
    
    Args:
        input_file (str): Path to the input file containing student records.
    
    Returns:
        dict: A dictionary with keys 'valid_count', 'invalid_count',
              'average_score', and 'passed_count'.
    """
    pass

# %% [markdown]
# ## Testing Your Solution
#
# Run the cells below to test your implementation with the provided examples.

# %%
import os

test_data_1 = """Alice,25,85,90,88
Bob,24,72,68,75
Charlie,23,95,92,98"""

with open('students.txt', 'w') as f:
    f.write(test_data_1)

result = process_student_records('students.txt')
print("Test 1 Result:", result)

if os.path.exists('report.txt'):
    with open('report.txt', 'r') as f:
        print("\nGenerated Report:\n")
        print(f.read())

# %%
test_data_2 = """Alice,25,85,90,88
Bob,24,72,invalid,75
Charlie,23,95,92,98
Diana,26
Eve,22,55,60,58"""

with open('students.txt', 'w') as f:
    f.write(test_data_2)

result = process_student_records('students.txt')
print("Test 2 Result:", result)

if os.path.exists('report.txt'):
    with open('report.txt', 'r') as f:
        print("\nGenerated Report:\n")
        print(f.read())

# %%
test_data_3 = """Alice,25,85,150,88
Bob,24,72,68"""

with open('students.txt', 'w') as f:
    f.write(test_data_3)

result = process_student_records('students.txt')
print("Test 3 Result:", result)

if os.path.exists('report.txt'):
    with open('report.txt', 'r') as f:
        print("\nGenerated Report:\n")
        print(f.read())

# %% [markdown]
# ## Hints (if you get stuck)
#
# - Use a `with` statement to open files safely.
# - Split each line by commas to extract fields.
# - Use try-except blocks to catch conversion errors when parsing scores.
# - Validate that scores are between 0 and 100.
# - Keep track of valid and invalid record counts separately.
# - Calculate the average only from valid scores.
# - Format the output report exactly as shown in the examples.
