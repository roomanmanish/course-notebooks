# %% [markdown]
# # Clean and Analyze a Real-World Dataset
#
# ## Scenario
#
# You work as a junior data analyst at a retail company. Your team has collected customer transaction data, but it's messy. Your task is to clean the data and extract meaningful insights.
#
# ## What You'll Do
#
# 1. Load a CSV file with messy data (missing values, duplicates, inconsistent types).
# 2. Clean the data systematically.
# 3. Explore the cleaned data to find patterns.
# 4. Generate a summary report with key insights.
#
# ## Expected Outputs
#
# By the end, you should have:
# - A cleaned DataFrame ready for analysis.
# - Summary statistics and exploratory findings.
# - A report dictionary containing:
#   - Cleaning metrics (original rows, final rows, missing values handled).
#   - Top 3 regions by total sales.
#   - Average order value by customer segment.
#   - At least one additional insight.

# %% [markdown]
# ## Step 1: Load and Inspect the Raw Data
#
# Start by loading the CSV file and examining its structure. What do you see? How many rows and columns? Are there any obvious issues?

# %%
import pandas as pd
import numpy as np

# Load the dataset
df_raw = None  # Load the CSV file here

# Inspect the raw data
# Display shape, first few rows, data types, and missing value counts
pass

# %% [markdown]
# ## Step 2: Clean the Data
#
# Now clean the data by:
# - Handling missing values (decide: drop, fill, or impute?).
# - Removing duplicate rows.
# - Converting data types appropriately (e.g., dates, numeric values).
#
# Document your cleaning decisions and the metrics (rows before/after, missing values handled).

# %%
# Record metrics before cleaning
original_rows = None
missing_values_before = None

# Create a copy for cleaning
df_clean = df_raw.copy()

# Clean the data
# Handle missing values
# Remove duplicates
# Convert data types
pass

# Record metrics after cleaning
final_rows = None
missing_values_after = None

# %% [markdown]
# ## Step 3: Exploratory Data Analysis
#
# Analyze the cleaned data:
# - Summary statistics (describe, info).
# - Unique value counts.
# - Group by region and sum sales.
# - Group by customer segment and calculate average order value.
# - Find any other interesting pattern.

# %%
# Summary statistics
pass

# %%
# Group by region and sum sales
sales_by_region = None
pass

# %%
# Group by customer segment and calculate average order value
avg_order_by_segment = None
pass

# %%
# Additional exploration: find one more insight
# (e.g., most common product category, highest transaction count by month, etc.)
additional_insight = None
pass

# %% [markdown]
# ## Step 4: Generate Summary Report
#
# Compile all your findings into a summary report dictionary. This should include:
# - Cleaning metrics.
# - Top 3 regions by total sales.
# - Average order value by customer segment.
# - Your additional insight.

# %%
# Create the summary report
summary_report = {}

# Add cleaning metrics
# Add top 3 regions by sales
# Add average order value by segment
# Add your additional insight

pass

# Display the report
print("=== SUMMARY REPORT ===")
for key, value in summary_report.items():
    print(f"{key}: {value}")
