# %% [markdown]
# # Grade Calculator Lab
#
# ## Problem
#
# You are building a **Grade Calculator** — a program that helps a teacher quickly compute a student's final grade.
#
# Imagine a student named Alex has taken three tests in Python class:
# - Test 1: 85 points
# - Test 2: 92 points
# - Test 3: 78 points
#
# The teacher wants to:
# 1. **Calculate the average** of the three scores.
# 2. **Assign a letter grade** based on that average using a standard grading scale.
# 3. **Display a personalized message** that includes the student's name, average score, and letter grade.
#
# Your task is to write a Python program that:
# - Prompts the user to enter a student's name and three test scores (as numbers).
# - Computes the average of those three scores.
# - Determines the letter grade according to this scale:
#   - **A**: average >= 90
#   - **B**: average >= 80 and < 90
#   - **C**: average >= 70 and < 80
#   - **D**: average >= 60 and < 70
#   - **F**: average < 60
# - Prints a message showing the student's name, average score (rounded to 2 decimal places), and letter grade.

# %% [markdown]
# ## Expected Output
#
# **Example 1:**
# ```
# Enter student name: Alice
# Enter test 1 score: 95
# Enter test 2 score: 88
# Enter test 3 score: 92
#
# Alice's average score is 91.67 and letter grade is A.
# ```
#
# **Example 2:**
# ```
# Enter student name: Bob
# Enter test 1 score: 75
# Enter test 2 score: 82
# Enter test 3 score: 71
#
# Bob's average score is 76.0 and letter grade is C.
# ```
#
# **Example 3:**
# ```
# Enter student name: Charlie
# Enter test 1 score: 58
# Enter test 2 score: 62
# Enter test 3 score: 55
#
# Charlie's average score is 58.33 and letter grade is F.
# ```

# %%
def grade_calculator():
    """
    Prompts the user for a student name and three test scores.
    Calculates the average, assigns a letter grade, and prints the result.
    """
    pass
