# %% [markdown]
# # Weather Data Analysis and Visualization
#
# ## Your Task
#
# Imagine you work for a meteorological agency. Every day, weather stations collect data—temperature, humidity, wind speed, precipitation, and conditions. Your job is to take raw data and turn it into insights.
#
# **Story**: A farmer wants to know: *What months are safest for planting? When does it rain most? How does humidity affect temperature?* A city planner asks: *What's the average temperature by season? Are there patterns in wind speed?* These questions can only be answered with clean data and clear visualizations.
#
# In this lab, you'll:
# 1. Load weather data from a CSV file
# 2. Clean it (handle missing values, create new features)
# 3. Visualize patterns (trends, distributions, relationships)
# 4. Export results for stakeholders
#
# This mirrors real-world data workflows: **fetch → clean → analyze → visualize → export**.
#
# ---
#
# ## Problem Statement
#
# You have a CSV file (`weather_data.csv`) with weather observations. Your goal is to:
#
# 1. **Load and explore** the data
# 2. **Clean it**: handle missing values, convert data types, create meaningful new columns
# 3. **Visualize** at least 3 different aspects (trends, distributions, comparisons)
# 4. **Export** the cleaned data to CSV and Excel formats
# 5. **Generate summary statistics** by weather condition
#
# ## Expected Output
#
# When you finish, you should have:
# - A cleaned DataFrame with no missing values and a new `temp_category` column
# - 3+ publication-quality visualizations (line plot, bar chart, heatmap/histogram)
# - Files: `processed_weather.csv`, `processed_weather.xlsx`, `weather_summary.csv`
# - Summary statistics showing mean temperature, humidity, and count by condition
#
# ---

# %% [markdown]
# ## Step 1: Load and Explore the Data
#
# Start by loading the weather data and understanding its structure.

# %%
import pandas as pd
            import numpy as np
            import matplotlib.pyplot as plt
            import seaborn as sns
            from datetime import datetime
            
            # Load the weather data
            df = pd.read_csv('weather_data.csv')
            
            # Display basic info
            print("Dataset shape:", df.shape)
            print("\nFirst few rows:")
            print(df.head())
            print("\nData types:")
            print(df.dtypes)
            print("\nMissing values:")
            print(df.isnull().sum())
            print("\nBasic statistics:")
            print(df.describe())

# %% [markdown]
# ## Step 2: Clean and Transform the Data
#
# Handle missing values, convert data types, and create new features. Your cleaned data should have:
# - No missing values (fill or drop as appropriate)
# - `date` column as datetime type
# - A new `temp_category` column that categorizes temperature (e.g., "Cold" if temp < 10, "Mild" if 10-20, "Warm" if > 20)
# - All numeric columns properly typed

# %%
def clean_weather_data(dataframe):
            """
            Clean and transform weather data.
            
            - Handle missing values
            - Convert date column to datetime
            - Create temp_category column
            - Ensure numeric columns are properly typed
            
            Returns: cleaned DataFrame
            """
            pass

# %%
# Apply cleaning
            df_clean = clean_weather_data(df)
            
            print("Cleaned data shape:", df_clean.shape)
            print("\nFirst few rows:")
            print(df_clean.head())
            print("\nMissing values after cleaning:")
            print(df_clean.isnull().sum())
            print("\nData types:")
            print(df_clean.dtypes)
            print("\nTemperature categories:")
            print(df_clean['temp_category'].value_counts())

# %% [markdown]
# ## Step 3: Create Visualizations
#
# Create at least 3 different visualizations to explore the data. Consider:
# - **Line plot**: How does temperature change over time?
# - **Bar chart**: What is the average temperature by weather condition?
# - **Heatmap or histogram**: What is the distribution of temperature or correlation between variables?
#
# Each visualization should have clear titles, labels, and be publication-ready.

# %%
def create_visualizations(dataframe):
            """
            Create at least 3 publication-quality visualizations.
            
            Expected:
            - Line plot of temperature over time
            - Bar chart of average temperature by condition
            - Heatmap or histogram showing distribution/correlation
            
            Each plot should have:
            - Clear title
            - Labeled axes
            - Appropriate colors and formatting
            
            Returns: None (displays plots)
            """
            pass

# %%
# Create visualizations
            create_visualizations(df_clean)

# %% [markdown]
# ## Step 4: Generate Summary Statistics
#
# Create a summary table showing aggregated statistics by weather condition.

# %%
def generate_summary_statistics(dataframe):
            """
            Generate summary statistics grouped by weather condition.
            
            Expected columns in output:
            - condition: weather condition
            - avg_temperature: mean temperature for that condition
            - avg_humidity: mean humidity for that condition
            - avg_precipitation: mean precipitation for that condition
            - count: number of observations
            
            Returns: DataFrame with summary statistics
            """
            pass

# %%
# Generate summary
            summary_stats = generate_summary_statistics(df_clean)
            print("Summary Statistics by Weather Condition:")
            print(summary_stats)
            print("\nSummary shape:", summary_stats.shape)

# %% [markdown]
# ## Step 5: Export Results
#
# Export the cleaned data and summary statistics to CSV and Excel formats.

# %%
def export_results(cleaned_dataframe, summary_dataframe):
            """
            Export cleaned data and summary statistics.
            
            Creates:
            - processed_weather.csv: cleaned data
            - processed_weather.xlsx: cleaned data in Excel
            - weather_summary.csv: summary statistics
            
            Returns: None
            """
            pass

# %%
# Export results
            export_results(df_clean, summary_stats)
            print("\nExport complete!")
            print("Files created:")
            print("  - processed_weather.csv")
            print("  - processed_weather.xlsx")
            print("  - weather_summary.csv")

# %% [markdown]
# ## Verification
#
# Verify that all outputs are correct by checking file sizes and contents.

# %%
import os
            
            # Check that files exist
            files_to_check = ['processed_weather.csv', 'processed_weather.xlsx', 'weather_summary.csv']
            for file in files_to_check:
                if os.path.exists(file):
                    size = os.path.getsize(file)
                    print(f"✓ {file} exists ({size} bytes)")
                else:
                    print(f"✗ {file} NOT FOUND")
            
            # Verify cleaned data
            print(f"\nCleaned data: {df_clean.shape[0]} rows, {df_clean.shape[1]} columns")
            print(f"Summary stats: {summary_stats.shape[0]} rows, {summary_stats.shape[1]} columns")
