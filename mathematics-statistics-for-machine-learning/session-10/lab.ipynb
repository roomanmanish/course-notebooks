# %% [markdown]
# # Applying Bayes' Theorem to Classification Scenarios
#
# In this lab you will implement conditional probability and Bayes' theorem, then apply them to two classic scenarios: **spam email detection** and **medical diagnostic testing**.
#
# Work through the sections below. Each markdown cell explains a concept; the code cell right after it contains a function stub for you to complete.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## The dataset
#
# `data.csv` contains 15 emails. Each row records whether the email contains certain words (`contains_free`, `contains_offer`, `contains_urgent`) and whether the email was actually spam (`is_spam`).
#
# Load it below.

# %%
emails_df = pd.read_csv("data.csv")
emails_df

# %% [markdown]
# ## Task 1: Conditional probability from data
#
# Implement a function that computes `P(event_col == event_value | given_col == given_value)` directly by counting rows of `df`. Return a plain Python float between 0 and 1.

# %%
def conditional_probability(df, event_col, given_col, event_value=1, given_value=1):
    pass

# %% [markdown]
# ## Task 2: Bayes' theorem, the general formula
#
# Implement the general Bayes' theorem formula that turns a prior probability, a likelihood, and the probability of the evidence into a posterior probability.

# %%
def bayes_theorem(prior, likelihood, evidence):
    pass

# %% [markdown]
# ## Task 3: Total probability of the evidence
#
# Before you can use `bayes_theorem`, you often need the overall probability of the evidence, considering both the case where the hypothesis is true and where it is false. Implement that here.

# %%
def total_evidence(prior_a, likelihood_b_given_a, prior_not_a, likelihood_b_given_not_a):
    pass

# %% [markdown]
# ## Task 4: Spam posterior via Bayes' theorem
#
# Given a dataframe and the name of a word column, compute priors and likelihoods from the data and combine them with `bayes_theorem` (and `total_evidence`) to get the posterior probability that an email is spam given that it contains that word. The result should agree with the direct count computed by `conditional_probability`.

# %%
def spam_posterior(df, word_col, spam_col='is_spam'):
    pass

# %% [markdown]
# ## Task 5: Diagnostic test posterior
#
# A patient takes a diagnostic test and gets a **positive** result. Given the disease's `prevalence` in the population, the test's `sensitivity` (probability of a positive result given the disease is present), and its `specificity` (probability of a negative result given the disease is absent), compute the probability the patient actually has the disease.

# %%
def diagnostic_posterior(prevalence, sensitivity, specificity):
    pass

# %% [markdown]
# ## Explore (optional, not graded)
#
# Try calling your functions on the email dataset and on a few diagnostic-test scenarios of your own choosing. How does the posterior probability change as sensitivity or prevalence changes? Feel free to plot this.
