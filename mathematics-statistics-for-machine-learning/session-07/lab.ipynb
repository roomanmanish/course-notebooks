# %% [markdown]
# # Gradient Descent from Scratch
#
# We will minimize the quadratic loss surface
#
# ```
# loss(x) = (x - 4)**2 + 3
# ```
#
# which has a single minimum at `x = 4` where `loss = 3`.
#
# Your job: implement `loss`, `gradient`, `gradient_descent`, and `explore_learning_rates` below, then use them to visualize convergence and divergence.

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Step 1 — The loss surface and its slope
#
# `loss(x)` should accept a Python number or a NumPy array `x` and return the loss value(s).
#
# `gradient(x)` should return the slope of `loss` at `x` (same shape as `x`).

# %%
def loss(x):
    """Return the value of the loss surface at x (scalar or array)."""
    pass


def gradient(x):
    """Return the slope of the loss surface at x (scalar or array)."""
    pass

# %% [markdown]
# ## Step 2 — The descent loop
#
# `gradient_descent(start_x, learning_rate, n_iterations)` should repeatedly update `x` using the gradient, and return a NumPy array containing every value of `x` visited, **including the starting value**. The returned array must therefore have length `n_iterations + 1`.

# %%
def gradient_descent(start_x, learning_rate, n_iterations):
    """Return an array of x-values visited during gradient descent,
    starting with start_x and having length n_iterations + 1."""
    pass

# %% [markdown]
# Try it out and plot the loss surface together with the path your descent took, and the loss value over iterations.

# %%
history = gradient_descent(start_x=0, learning_rate=0.1, n_iterations=50)
print(history[:5], '...', history[-5:])

# %% [markdown]
# ## Step 3 — Comparing learning rates
#
# `explore_learning_rates(start_x, learning_rates, n_iterations)` should run `gradient_descent` once per value in the `learning_rates` list, and return a dictionary mapping each learning rate to its history array.

# %%
def explore_learning_rates(start_x, learning_rates, n_iterations):
    """Return a dict {learning_rate: history_array} for each rate in learning_rates."""
    pass

# %% [markdown]
# Use the cell below to plot the descent path on the loss surface, and to plot loss-vs-iteration for a few different learning rates (try something small, something well-tuned, and something too large). What do you observe about each one?

# %%
xs = np.linspace(-6, 14, 400)
plt.plot(xs, loss(xs))
plt.xlabel('x')
plt.ylabel('loss(x)')
plt.title('Loss surface')
plt.show()
