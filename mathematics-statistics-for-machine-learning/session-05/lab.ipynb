# %% [markdown]
# # Plotting and Tuning Parametrized Model Functions
#
# ## Problem
#
# ML models are functions of their inputs, shaped by parameters (weights, bias). In this notebook you will implement a linear function, a quadratic function, a sigmoid function, and a multivariable linear function, then visualize how their parameters change the resulting curve.
#
# ## Expected output
#
# - `linear_function(np.array([0,1,2]), w=2, b=3)` -> `[3, 5, 7]`
# - `quadratic_function(np.array([0,1,2]), a=1, b=0, c=0)` -> `[0, 1, 4]`
# - `sigmoid_function(0)` -> `0.5`
# - `multivariable_linear([[1,2],[3,4]], weights=[1,1], bias=0)` -> `[3, 7]`
# - Plots showing how the line/curve shape changes when you change parameters.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part 1: Implement the functions
#
# Each function must accept a scalar or a NumPy array for `x` (or a 2D array `X` for the multivariable case) and return the corresponding output(s).

# %%
def linear_function(x, w, b):
    """Return w*x + b. x may be a scalar or a NumPy array."""
    raise NotImplementedError


def quadratic_function(x, a, b, c):
    """Return a*x**2 + b*x + c. x may be a scalar or a NumPy array."""
    raise NotImplementedError


def sigmoid_function(x):
    """Return the sigmoid of x, squashing values into (0, 1). x may be a scalar or a NumPy array."""
    raise NotImplementedError


def multivariable_linear(X, weights, bias=0.0):
    """Return a prediction for every row of X, combining multiple features with weights and a bias.
    X has shape (n_samples, n_features); weights has shape (n_features,).
    The result must have shape (n_samples,)."""
    raise NotImplementedError

# %% [markdown]
# ## Part 2: Sanity check your functions
#
# Try calling each function with a few small inputs and confirm the outputs match what you'd expect by hand.

# %%
# Quick manual checks -- edit freely, this cell is not graded

# %% [markdown]
# ## Part 3: Visualize the linear function
#
# Plot `linear_function` over a range of x values for at least two different `(w, b)` pairs on the same axes. Add a markdown note describing what changing `w` and `b` does to the line.

# %%
# Your linear plotting code here

# %% [markdown]
# ## Part 4: Visualize the quadratic and sigmoid functions
#
# Plot `quadratic_function` and `sigmoid_function` over a reasonable range of x values (e.g. -10 to 10). Add a markdown note describing the shape of each curve.

# %%
# Your quadratic/sigmoid plotting code here

# %% [markdown]
# ## Part 5: A multivariable model on real-ish data
#
# Load `data.csv` into a variable named `housing_df`. It has columns `size_sqft`, `bedrooms`, `price`. Choose your own weights and bias, then use `multivariable_linear` to compute a predicted price for every row using `size_sqft` and `bedrooms` as the two features. Store the predictions in a variable named `predicted_prices`.

# %%
housing_df = pd.read_csv("data.csv")

# Choose weights and bias, compute predicted_prices using multivariable_linear
