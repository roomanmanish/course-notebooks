# %% [markdown]
# # Simulating and Estimating Probabilities
#
# Build a small toolkit that simulates simple probability experiments with NumPy and compares empirical results against theoretical predictions.
#
# You will implement:
# 1. `simulate_coin_flips` -- simulate biased binary outcomes.
# 2. `empirical_probability` -- estimate P(value) from simulated outcomes.
# 3. `simulate_class_labels` -- draw class labels according to given prior probabilities.
# 4. `estimate_class_probabilities` -- estimate each class's empirical probability from labels.
# 5. `simulate_independent_events` -- simulate two independent binary events together.
# 6. `empirical_joint_probability` -- estimate P(A and B) from simulated joint outcomes.
# 7. `theoretical_joint_probability_independent` -- the value the multiplication rule predicts for independent events.

# %% [markdown]
# ## Expected output
#
# For large sample sizes, empirical estimates should land close (within a few percent) to the theoretical values you supply as parameters. For example, flipping a coin with `p_heads=0.3` many times and computing `empirical_probability(outcomes, 1)` should give something near `0.3`. Simulating two independent events with `p_a=0.5` and `p_b=0.3` and computing `empirical_joint_probability` should give something near `theoretical_joint_probability_independent(0.5, 0.3)` which equals `0.15`.

# %%
import numpy as np

# %%
def simulate_coin_flips(n, p_heads=0.5, seed=None):
    """Return an array-like of length n containing 1 (heads) and 0 (tails),
    where each entry is 1 with probability p_heads. seed controls reproducibility.
    """
    pass

# %%
def empirical_probability(outcomes, value=1):
    """Return the fraction of entries in outcomes that equal value."""
    pass

# %%
def simulate_class_labels(n, class_probs, seed=None):
    """class_probs is a dict mapping a class name (e.g. 'spam') to its
    probability; the values sum to 1. Return a list/array of length n
    containing class names drawn according to those probabilities.
    """
    pass

# %%
def estimate_class_probabilities(labels, classes):
    """Given a collection of labels and a list of class names, return a
    dict mapping each class name to the fraction of labels equal to it.
    """
    pass

# %%
def simulate_independent_events(n, p_a, p_b, seed=None):
    """Simulate n trials of two independent binary events A and B with
    success probabilities p_a and p_b respectively. Return a tuple
    (a_outcomes, b_outcomes), each an array-like of 0/1 of length n.
    """
    pass

# %%
def empirical_joint_probability(a_outcomes, b_outcomes):
    """Return the fraction of trials where both a_outcomes and
    b_outcomes equal 1 at the same position.
    """
    pass

# %%
def theoretical_joint_probability_independent(p_a, p_b):
    """Return the joint probability P(A and B) predicted for two
    independent events with individual probabilities p_a and p_b.
    """
    pass

# %% [markdown]
# ## Try it out
#
# Once your functions are implemented, use the cells below (or add your own) to run simulations with different sample sizes and probabilities, and observe how the empirical estimate gets closer to the theoretical value as n grows.

# %%
# Scratch space -- experiment here.
