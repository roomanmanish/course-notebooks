# %% [markdown]
# # ML Mathematics Capstone: End-to-End Analysis
#
# `data.csv` contains 15 students with columns `student_id, hours_studied, attendance_pct, previous_score, sleep_hours, final_score`.
#
# You will build a small end-to-end mathematical analysis of this dataset. Work through each section below, implementing the empty functions. Run every cell top to bottom when you're done.

# %%
import numpy as np
import pandas as pd

DATA_PATH = "data.csv"

def load_data(path=DATA_PATH):
    """Return the dataset as a pandas DataFrame."""
    raise NotImplementedError

df = load_data()
df

# %% [markdown]
# ## 1 & 2. Representing observations as vectors/matrices
#
# **Expected output:** `feature_matrix(df, ['hours_studied', 'final_score'])` returns a numeric numpy array with one row per student and one column per requested feature. `student_vector(df, 5, ['hours_studied', 'final_score'])` returns `array([15, 90])`.

# %%
def feature_matrix(df, columns):
    """Return a numpy array with the requested columns as a matrix."""
    raise NotImplementedError

def student_vector(df, student_id, columns):
    """Return the numeric feature vector for the given student_id as a 1-D numpy array."""
    raise NotImplementedError

# %% [markdown]
# ## 3. Comparing observations
#
# **Expected output:** `euclidean_distance(np.array([0, 0]), np.array([3, 4]))` returns `5.0`. `most_similar_student(df, 2, ['hours_studied', 'final_score'])` returns the `student_id` (an int) of the student closest to student 2, excluding student 2 itself.

# %%
def euclidean_distance(v1, v2):
    """Return the straight-line distance between two numeric vectors."""
    raise NotImplementedError

def most_similar_student(df, student_id, columns):
    """Return the student_id of the student closest to student_id (excluding itself) using the given feature columns."""
    raise NotImplementedError

# %% [markdown]
# ## 4. Probability & expected value
#
# **Expected output:** `probability_pass(df, threshold=50)` returns approximately `0.733` for this dataset. `expected_final_score(df)` returns the average final score across all students, approximately `64.87`.

# %%
def probability_pass(df, threshold=50):
    """Return the fraction of students whose final_score is >= threshold, as a float between 0 and 1."""
    raise NotImplementedError

def expected_final_score(df):
    """Return the expected (average) final_score across all students."""
    raise NotImplementedError

# %% [markdown]
# ## 5 & 6. Relationships, correlation vs. causation
#
# **Expected output:** `pearson_correlation(hours, scores)` returns a value close to `1.0`, indicating a strong positive linear relationship between hours studied and final score. `correlation_or_causation()` should return the single word that best describes what this analysis alone can responsibly claim: `'correlation'` or `'causation'`.

# %%
def pearson_correlation(x, y):
    """Return the Pearson correlation coefficient between two 1-D numeric sequences."""
    raise NotImplementedError

def correlation_or_causation():
    """Return the single word ('correlation' or 'causation') that best describes
    what an observed relationship in this dataset alone justifies claiming."""
    raise NotImplementedError

# %% [markdown]
# ## 7. Loss function & gradient descent
#
# **Expected output:** `mse(np.array([1, 2, 3]), np.array([1, 2, 4]))` returns approximately `0.333`. `gradient_descent(x, y, lr=0.01, epochs=5000)` returns `(slope, intercept, loss_history)`; for data generated from `y = 2x + 1`, the returned slope should end up close to `2.0`, the intercept close to `1.0`, and `loss_history` should show the loss decreasing from the first to the last epoch.

# %%
def mse(y_true, y_pred):
    """Return the mean squared error between y_true and y_pred."""
    raise NotImplementedError

def gradient_descent(x, y, lr=0.01, epochs=1000):
    """Fit y ~ slope * x + intercept by iteratively updating slope and intercept
    to reduce the mean squared error. Return (slope, intercept, loss_history)
    where loss_history is a list with the loss value recorded at each epoch
    (length == epochs)."""
    raise NotImplementedError

# %% [markdown]
# ## 8. Connecting to future ML algorithms
#
# Write a short explanation (a few sentences) connecting each technique you used above to how it shows up in real machine learning algorithms (for example: distance in nearest-neighbor methods, probability in classifiers, correlation in feature selection, gradient descent in training models). Assign your explanation to the `explanation_text` string variable below.

# %%
explanation_text = ""
explanation_text
