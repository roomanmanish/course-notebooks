# %% [markdown]
# # Generating and visualizing probability distributions
#
# ## Problem
# Implement the probability functions and random sample generators described in the lab instructions, then compare sampled histograms against the theoretical PMF/PDF curves for Bernoulli, Binomial, and Normal distributions.
#
# ## Expected output
# - `bernoulli_pmf(1, 0.3)` -> `0.3`
# - `binomial_pmf(2, 5, 0.5)` -> `0.3125`
# - `normal_pdf(0, 0, 1)` -> approx `0.3989`
# - `generate_normal_samples(10, 2, 5000, seed=3)` -> array whose mean is close to 10 and std close to 2
# - Sampling functions are reproducible: same `seed` => identical array every time.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Theoretical probability functions
# Implement the three functions below. Each returns a probability (PMF) or density (PDF) value, not a sample.

# %%
def bernoulli_pmf(k, p):
    """Return P(X=k) for a Bernoulli(p) random variable. k must be 0 or 1;
    any other k has probability 0."""
    raise NotImplementedError


def binomial_pmf(k, n, p):
    """Return P(X=k) for a Binomial(n, p) random variable (k successes out of n trials)."""
    raise NotImplementedError


def normal_pdf(x, mu, sigma):
    """Return the probability density f(x) for a Normal(mu, sigma) random variable."""
    raise NotImplementedError

# %% [markdown]
# ### Random sample generators
# Each function below must return a NumPy array of exactly `size` samples drawn from the named distribution, and must be reproducible: the same `seed` argument must always return the exact same array.

# %%
def generate_bernoulli_samples(p, size, seed=42):
    """Return a NumPy array of `size` samples drawn from Bernoulli(p)."""
    raise NotImplementedError


def generate_binomial_samples(n_trials, p, size, seed=42):
    """Return a NumPy array of `size` samples drawn from Binomial(n_trials, p)."""
    raise NotImplementedError


def generate_normal_samples(mu, sigma, size, seed=42):
    """Return a NumPy array of `size` samples drawn from Normal(mu, sigma)."""
    raise NotImplementedError

# %% [markdown]
# ### Summary statistic
# Given an array of samples, return its mean and standard deviation.

# %%
def sample_mean_std(samples):
    """Return a (mean, std) tuple of floats describing the given array of samples."""
    raise NotImplementedError

# %% [markdown]
# ### Explore: visualize samples vs theory
# Use the cells below (write your own code) to draw samples with each generator, plot a histogram of the samples, and overlay the theoretical PMF/PDF values computed with your functions above. Try different values of `p`, `n`, `mu`, `sigma`, and sample sizes and see how the histogram approaches the theoretical curve as the sample size grows. This exploration is not graded numerically, but is essential to build intuition for the rest of the course.

# %%
# Your exploration code here
