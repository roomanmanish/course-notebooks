# %% [markdown]
# # Grade Calculator Lab
#
# ## Problem
#
# You are building a **grade calculator** for a school. Your program must:
#
# 1. Accept test scores for one or more students (one student at a time).
# 2. For each student, calculate the **average** of their test scores.
# 3. Assign a **letter grade** based on the average:
#    - A: 90 or above
#    - B: 80 to 89
#    - C: 70 to 79
#    - D: 60 to 69
#    - F: below 60
# 4. Display the student's name, average score, and letter grade.
# 5. Ask the user if they want to process another student. Keep looping until they say no.
#
# ## Expected Output
#
# ### Example 1: Single student
# ```
# Student name: Alice
# Enter test score 1: 85
# Enter test score 2: 92
# Enter test score 3: 88
# Process another student? (yes/no): no
#
# Alice's average: 88.33
# Alice's grade: B
# ```
#
# ### Example 2: Multiple students
# ```
# Student name: Bob
# Enter test score 1: 95
# Enter test score 2: 98
# Process another student? (yes/no): yes
# Student name: Carol
# Enter test score 1: 65
# Enter test score 2: 72
# Enter test score 3: 68
# Process another student? (yes/no): no
#
# Bob's average: 96.50
# Bob's grade: A
# Carol's average: 68.33
# Carol's grade: D
# ```
#
# ### Example 3: Boundary case
# ```
# Student name: David
# Enter test score 1: 80
# Enter test score 2: 80
# Process another student? (yes/no): no
#
# David's average: 80.00
# David's grade: B
# ```

# %% [markdown]
# ## Your Solution
#
# Write your grade calculator below. Use variables, conditionals, and loops to solve the problem.

# %%
def calculate_grade(average):
    """
    Given an average score, return the letter grade.
    """
    pass


def process_student():
    """
    Process one student: get name, scores, calculate average and grade, display result.
    """
    pass


def main():
    """
    Main loop: process students until user says no.
    """
    pass


# Uncomment the line below to run your program
# main()

# %% [markdown]
# ## Hints
#
# - Use a `while` loop to keep asking for students until the user enters 'no'.
# - Use another loop (or a list) to collect multiple test scores for each student.
# - Use `if/elif/else` to determine the letter grade based on the average.
# - Use `input()` to read from the user and `print()` to display results.
# - Round the average to 2 decimal places using `round()` or string formatting.
