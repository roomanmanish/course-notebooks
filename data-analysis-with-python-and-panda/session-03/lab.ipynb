# %% [markdown]
# # Analyze Customer Behavior with Groupby and Visualizations
#
# ## Problem
#
# You have a dataset of customer transactions. Your task is to:
#
# 1. **Load and explore** the transaction data.
# 2. **Group and aggregate** the data by customer segment and month to calculate:
#    - Total spend per segment per month
#    - Purchase frequency (count of transactions) per segment per month
# 3. **Create visualizations** to show trends:
#    - A bar chart comparing total spend across customer segments
#    - A line chart showing how total spend changes over time for each segment
# 4. **Identify insights**: Find and report which customer segment has the highest total spend.
#
# ## Expected Output
#
# ### Aggregated Data
# After grouping by segment and month, your aggregated DataFrame should have columns:
# - Segment
# - Month
# - Total_Spend (sum of transaction amounts)
# - Purchase_Count (number of transactions)
#
# ### Bar Chart
# A bar chart titled "Total Spend by Customer Segment" showing total spend for each segment.
#
# ### Line Chart
# A line chart titled "Monthly Spend Trends by Segment" showing how spend changes over time for each segment.
#
# ### Insight
# A printed statement identifying the segment with the highest total spend.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Step 1: Load the Data
#
# Load the customer transaction dataset from `data.csv`.

# %%
# Load the data
df = pd.read_csv('data.csv')

# Display first few rows to understand the structure
df.head()

# %% [markdown]
# ## Step 2: Prepare the Data
#
# Convert the date column to datetime format and extract the month for grouping.

# %%
# Convert date column to datetime and extract month
df['Date'] = pd.to_datetime(df['Date'])
df['Month'] = df['Date'].dt.to_period('M')

df.head()

# %% [markdown]
# ## Step 3: Group and Aggregate
#
# Group the data by Segment and Month, then calculate total spend and purchase frequency.

# %%
# Group by Segment and Month, then aggregate
aggregated = None

aggregated

# %% [markdown]
# ## Step 4: Create Bar Chart
#
# Create a bar chart showing total spend by customer segment (summed across all months).

# %%
# Create bar chart for total spend by segment
segment_spend = None

plt.figure(figsize=(10, 6))
# Add bar chart code here
plt.title('Total Spend by Customer Segment')
plt.xlabel('Customer Segment')
plt.ylabel('Total Spend ($)')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 5: Create Line Chart
#
# Create a line chart showing monthly spend trends for each customer segment.

# %%
# Create line chart for monthly trends by segment
plt.figure(figsize=(12, 6))
# Add line chart code here
plt.title('Monthly Spend Trends by Segment')
plt.xlabel('Month')
plt.ylabel('Total Spend ($)')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 6: Identify Highest-Value Segment
#
# Find and print the customer segment with the highest total spend.

# %%
# Find the segment with the highest total spend
highest_segment = None
highest_spend = None

print(f"Highest-value segment: {highest_segment} with total spend of ${highest_spend:,.2f}")
