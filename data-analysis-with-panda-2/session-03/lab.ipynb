# %% [markdown]
# # Analyze Sales Performance by Region and Product
#
# ## Overview
# In this lab, you will use pandas `groupby()`, `agg()`, and `pivot_table()` to segment sales data and compute business insights.
#
# ## Dataset
# The file `data.csv` contains sales transactions with columns:
# - `Date`: Transaction date
# - `Region`: Geographic region (North, South, East, West)
# - `Product_Category`: Product category (Electronics, Clothing, Food, Home)
# - `Units_Sold`: Number of units sold
# - `Revenue`: Total revenue from transaction
#
# Load the data and explore it below.

# %%
import pandas as pd
import numpy as np

# Load the dataset
df = pd.read_csv('data.csv')

# Display first few rows
print("First 5 rows:")
print(df.head())

print("\nDataset shape:", df.shape)
print("\nData types:")
print(df.dtypes)

print("\nBasic statistics:")
print(df.describe())

# %% [markdown]
# ## Task 1: Regional Summary
#
# Complete the function `regional_summary(df)` to return a DataFrame with:
# - `Region`: The region name
# - `Total_Revenue`: Sum of revenue for that region
# - `Avg_Units_Sold`: Average units sold per transaction in that region
# - `Transaction_Count`: Number of transactions in that region
#
# Sort by `Total_Revenue` in descending order.

# %%
def regional_summary(df):
    """
    Group by Region and compute total revenue, average units sold, and transaction count.
    
    Args:
        df: pandas DataFrame with columns Region, Revenue, Units_Sold
    
    Returns:
        DataFrame with columns: Region, Total_Revenue, Avg_Units_Sold, Transaction_Count
        Sorted by Total_Revenue descending.
    """
    # TODO: Implement this function
    pass

# Test your function
result = regional_summary(df)
print("Regional Summary:")
print(result)
print("\nExpected columns: Region, Total_Revenue, Avg_Units_Sold, Transaction_Count")

# %% [markdown]
# ## Task 2: Top Product Categories
#
# Complete the function `top_categories(df, n=3)` to return the top `n` product categories by total revenue.
#
# Return a DataFrame with:
# - `Product_Category`: The category name
# - `Total_Revenue`: Sum of revenue for that category
#
# Sort by `Total_Revenue` in descending order.

# %%
def top_categories(df, n=3):
    """
    Find the top n product categories by total revenue.
    
    Args:
        df: pandas DataFrame with columns Product_Category, Revenue
        n: Number of top categories to return (default 3)
    
    Returns:
        DataFrame with columns: Product_Category, Total_Revenue
        Sorted by Total_Revenue descending, limited to top n rows.
    """
    # TODO: Implement this function
    pass

# Test your function
result = top_categories(df, n=3)
print("Top 3 Product Categories:")
print(result)
print("\nExpected columns: Product_Category, Total_Revenue")

# %% [markdown]
# ## Task 3: Revenue Pivot Table
#
# Complete the function `revenue_by_region_and_category(df)` to create a pivot table.
#
# Return a DataFrame with:
# - Index: Region names
# - Columns: Product_Category names
# - Values: Total revenue for each Region-Category combination
# - Missing values should be filled with 0

# %%
def revenue_by_region_and_category(df):
    """
    Create a pivot table of revenue by Region and Product_Category.
    
    Args:
        df: pandas DataFrame with columns Region, Product_Category, Revenue
    
    Returns:
        Pivot table (DataFrame) with regions as rows, categories as columns,
        total revenue as values. Fill missing values with 0.
    """
    # TODO: Implement this function
    pass

# Test your function
result = revenue_by_region_and_category(df)
print("Revenue by Region and Category:")
print(result)
print("\nExpected: Rows = Regions, Columns = Product_Categories, Values = Total_Revenue")

# %% [markdown]
# ## Task 4: Top Category Per Region
#
# Complete the function `top_category_per_region(df)` to find the best-performing product category in each region.
#
# Return a DataFrame with:
# - `Region`: The region name
# - `Top_Category`: The product category with highest revenue in that region
# - `Revenue`: The total revenue for that category in that region
#
# Sort by `Revenue` in descending order.

# %%
def top_category_per_region(df):
    """
    For each region, find the product category with the highest revenue.
    
    Args:
        df: pandas DataFrame with columns Region, Product_Category, Revenue
    
    Returns:
        DataFrame with columns: Region, Top_Category, Revenue
        Sorted by Revenue descending.
    """
    # TODO: Implement this function
    # Hint: Group by Region and Product_Category, sum Revenue,
    # then use nlargest(1, ...) or idxmax() to find the top category per region.
    pass

# Test your function
result = top_category_per_region(df)
print("Top Category Per Region:")
print(result)
print("\nExpected columns: Region, Top_Category, Revenue")

# %% [markdown]
# ## Task 5: Custom Aggregation
#
# Complete the function `custom_aggregation(df)` to compute multiple statistics grouped by Region.
#
# Return a DataFrame with:
# - `Region`: The region name
# - `Total_Revenue`: Sum of revenue
# - `Avg_Revenue_Per_Transaction`: Mean of revenue
# - `Std_Units_Sold`: Standard deviation of units sold
# - `Transaction_Count`: Count of transactions
#
# Sort by `Total_Revenue` in descending order.

# %%
def custom_aggregation(df):
    """
    Group by Region and compute custom aggregations.
    
    Args:
        df: pandas DataFrame with columns Region, Revenue, Units_Sold
    
    Returns:
        DataFrame with columns:
        - Region
        - Total_Revenue (sum)
        - Avg_Revenue_Per_Transaction (mean)
        - Std_Units_Sold (std)
        - Transaction_Count (count)
        Sorted by Total_Revenue descending.
    """
    # TODO: Implement this function
    # Hint: Use groupby().agg() with a dictionary mapping column names to functions.
    pass

# Test your function
result = custom_aggregation(df)
print("Custom Aggregation by Region:")
print(result)
print("\nExpected columns: Region, Total_Revenue, Avg_Revenue_Per_Transaction, Std_Units_Sold, Transaction_Count")

# %% [markdown]
# ## Summary
#
# You have completed five key data analysis tasks:
# 1. Segmented sales by region and computed regional metrics.
# 2. Identified top-performing product categories.
# 3. Created a pivot table for cross-regional, cross-category analysis.
# 4. Ranked product categories within each region.
# 5. Computed custom aggregations for deeper insights.
#
# These techniques are fundamental for business intelligence and exploratory data analysis.
