# %% [markdown]
# # Load and Explore a Sales Dataset
#
# ## Instructions
#
# Complete each TODO cell below. Load a CSV file, inspect its structure, and answer questions about the data using Pandas.
#
# Read the instructions in `instructions_md` for detailed examples and guidance.

# %%
# TODO: Import pandas
# You will need this for all tasks
import pandas as pd

# %% [markdown]
# ### Task 1: Load the CSV file
#
# Load the file `data.csv` into a DataFrame named `df`. This file contains sales transaction data.

# %%
# TODO: Load data.csv into a DataFrame named 'df'
df = None  # Replace None with your code

# %% [markdown]
# ### Task 2: Inspect shape and columns
#
# Print the shape of the DataFrame (number of rows and columns) and list all column names.

# %%
# TODO: Print the shape and column names
# Hint: Use df.shape and df.columns
print("Shape:", None)  # Replace None
print("Columns:", None)  # Replace None

# %% [markdown]
# ### Task 3: View the first 5 rows
#
# Display the first 5 rows of the DataFrame.

# %%
# TODO: Display the first 5 rows
# Hint: Use df.head()
df.head()

# %% [markdown]
# ### Task 4: Check data types
#
# Display the data type of each column.

# %%
# TODO: Print the data types of all columns
# Hint: Use df.dtypes
print(df.dtypes)

# %% [markdown]
# ### Task 5: Select specific columns and rows
#
# Select only the `product` and `price` columns for the first 10 rows. Store the result in a variable named `product_price_subset`.

# %%
# TODO: Select 'product' and 'price' columns for the first 10 rows
# Hint: Use df[['col1', 'col2']].head(10) or df[['col1', 'col2']].iloc[0:10]
product_price_subset = None  # Replace None with your code
print(product_price_subset)

# %% [markdown]
# ### Task 6: Filter rows by condition
#
# Filter the DataFrame to show only rows where `quantity` > 5. Store the result in a variable named `high_quantity`.

# %%
# TODO: Filter rows where quantity > 5
# Hint: Use df[df['quantity'] > 5]
high_quantity = None  # Replace None with your code
print(f"Rows with quantity > 5: {high_quantity.shape[0]}")
print(high_quantity.head())

# %% [markdown]
# ### Task 7: Count unique values
#
# Count the number of unique regions in the dataset. Store the result in a variable named `unique_regions`.

# %%
# TODO: Count unique regions
# Hint: Use df['region'].nunique()
unique_regions = None  # Replace None with your code
print(f"Number of unique regions: {unique_regions}")

# %% [markdown]
# ### Task 8: Create a derived column
#
# Calculate the total revenue for each transaction (quantity × price) and add it as a new column named `revenue` to the DataFrame.

# %%
# TODO: Create a 'revenue' column by multiplying quantity and price
# Hint: df['revenue'] = df['quantity'] * df['price']
df['revenue'] = None  # Replace None with your code
print(df[['product', 'quantity', 'price', 'revenue']].head())

# %% [markdown]
# ## Summary
#
# You have successfully:
# 1. Loaded a CSV file into a Pandas DataFrame
# 2. Inspected the structure (shape, columns, data types)
# 3. Navigated the data using indexing and selection methods
# 4. Filtered and transformed data
#
# These are core skills for any data analysis workflow!
