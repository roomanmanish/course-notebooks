# %% [markdown]
# # Prompt Engineering Experiments
#
# ## Learning Goal
# Understand how prompt clarity, context, and examples affect the quality of AI assistant responses.
#
# ## The Story
# Imagine you are a manager at a customer service company. You need to train a new AI assistant to classify customer feedback. On day one, you give it a vague instruction: "Classify feedback." The assistant is confused and gives inconsistent results. On day two, you provide clear instructions with examples: "Classify feedback as positive, neutral, or negative. Example: 'Great service!' → positive. Example: 'Okay, nothing special' → neutral. Example: 'Terrible experience' → negative." Now the assistant is consistent and accurate.
#
# This is **prompt engineering**—the art of writing clear, well-structured instructions to get better responses from AI. In this lab, you will run experiments to discover these principles yourself.

# %% [markdown]
# ## Part 1: Setup and Mock LLM Service
#
# We will use a **mock LLM service** (simulated locally) to avoid external API calls. This service simulates how a real LLM responds to different prompt styles.

# %%
import json
import pandas as pd
from typing import List, Dict

# Mock LLM Service (simulates an AI assistant)
# In a real scenario, this would call an API like OpenAI or Hugging Face
class MockLLMService:
    """
    A simulated LLM that responds differently based on prompt quality.
    - Vague prompts → vague, inconsistent responses
    - Clear prompts with examples → focused, consistent responses
    """
    
    def __init__(self):
        pass
    
    def generate(self, prompt: str) -> str:
        """
        Simulate LLM response based on prompt quality.
        Returns a response string.
        """
        raise NotImplementedError("Implement the generate method")

# Initialize the mock service
llm = MockLLMService()

# %% [markdown]
# ## Part 2: Design Your Prompt Variations
#
# Create at least 3 different prompts that test different aspects of prompt engineering. For example:
# - **Variation 1**: A vague prompt (e.g., "Tell me about Python")
# - **Variation 2**: A clearer prompt with more context (e.g., "Explain what Python is used for in data science")
# - **Variation 3**: A very specific prompt with examples (e.g., "List 3 uses of Python in data science. Format: Use 1: [description]. Use 2: [description]. Use 3: [description].")
#
# Or test a different aspect:
# - **Variation 1**: Sentiment classification without examples
# - **Variation 2**: Sentiment classification with examples (few-shot prompting)
# - **Variation 3**: Sentiment classification with examples and explicit output format
#
# Define your prompts below:

# %%
# Define your prompt variations
# Each prompt should test a different aspect of prompt engineering

prompts = {
    # Example structure (replace with your own):
    # "prompt_name": "your prompt text here",
}

# Verify you have at least 3 prompts
assert len(prompts) >= 3, "You must define at least 3 prompt variations"
print(f"Defined {len(prompts)} prompt variations")
for name, text in prompts.items():
    print(f"  - {name}: {text[:60]}...")

# %% [markdown]
# ## Part 3: Run Experiments
#
# Send each prompt to the mock LLM and collect responses. Store the results in a structured format (e.g., a list of dictionaries or a DataFrame).

# %%
def run_experiments(prompts: Dict[str, str], llm_service: MockLLMService) -> List[Dict]:
    """
    Send each prompt to the LLM and collect responses.
    
    Args:
        prompts: Dictionary of {prompt_name: prompt_text}
        llm_service: The mock LLM service
    
    Returns:
        List of dictionaries with keys: 'prompt_name', 'prompt_text', 'response'
    """
    raise NotImplementedError("Implement the run_experiments function")

# Run the experiments
results = run_experiments(prompts, llm)
print(f"Collected {len(results)} responses")

# %% [markdown]
# ## Part 4: Analyze Results
#
# Compare the responses from different prompt variations. Look for patterns:
# - Which prompts produced clearer, more structured responses?
# - Which prompts led to vague or inconsistent outputs?
# - What role did examples, context, and specificity play?

# %%
def analyze_results(results: List[Dict]) -> pd.DataFrame:
    """
    Convert results into a DataFrame for easy comparison.
    
    Args:
        results: List of experiment results
    
    Returns:
        DataFrame with columns: 'prompt_name', 'prompt_text', 'response'
    """
    raise NotImplementedError("Implement the analyze_results function")

# Create analysis DataFrame
df_results = analyze_results(results)
print(df_results)

# %% [markdown]
# ## Part 5: Draw Conclusions
#
# Based on your experiments, what did you learn about effective prompt engineering? Write 1–2 sentences summarizing your key findings.

# %%
# Write your conclusion here
conclusion = """
Replace this text with your conclusion about what you learned from the experiments.
What made some prompts more effective than others?
"""

print("Conclusion:")
print(conclusion)
