# %% [markdown]
# # Bank Account Class
#
# ## Problem
#
# Build a `BankAccount` class that models a simple bank account. The class should allow customers to:
#
# - Create an account with a holder name and initial balance
# - Deposit money into the account
# - Withdraw money (only if sufficient funds exist)
# - Check the current balance
#
# **Key Rule:** Withdrawals that would result in a negative balance must be rejected.

# %% [markdown]
# ## Expected Behavior
#
# When you finish, your class should work like this:
#
# ```python
# # Create an account
# account = BankAccount('Alice', 1000)
#
# # Check balance
# account.check_balance()  # Should return 1000
#
# # Deposit money
# account.deposit(500)
# account.check_balance()  # Should return 1500
#
# # Withdraw money (success)
# account.withdraw(300)  # Should return True
# account.check_balance()  # Should return 1200
#
# # Try to withdraw more than balance (failure)
# account.withdraw(2000)  # Should return False
# account.check_balance()  # Should still be 1200 (unchanged)
# ```

# %%
class BankAccount:
    """A simple bank account class."""
    
    def __init__(self, account_holder, balance):
        """Initialize a bank account with holder name and initial balance."""
        pass
    
    def deposit(self, amount):
        """Add money to the account."""
        pass
    
    def withdraw(self, amount):
        """Remove money from the account if sufficient funds exist."""
        pass
    
    def check_balance(self):
        """Return the current balance."""
        pass

# %% [markdown]
# ## Test Your Implementation
#
# Use the cells below to test your `BankAccount` class. Try different scenarios:

# %%
# Test 1: Create an account and check balance
account1 = BankAccount('Alice', 1000)
print(f'Account holder: {account1.account_holder}')
print(f'Balance: {account1.check_balance()}')
