# %% [markdown]
# # Your First Python Program: Personal Profile Printer
#
# ## Welcome!
#
# In this lab, you will create your first Python program. You will learn how to:
# - Store information in **variables**
# - Use Python's basic **data types** (strings, integers)
# - Print formatted output to the console
#
# Let's start by understanding the task.

# %% [markdown]
# ## The Task: Build an Employee Profile Card
#
# Imagine you work at a company's HR department. Every time a new employee joins, you need to create a welcome card that displays their information in a nice, organized format.
#
# Your job is to write a Python program that:
# 1. Stores a person's details (name, age, city, job title) in variables
# 2. Prints out a formatted profile card
#
# The profile card should have:
# - A border made of equal signs (========)
# - A centered title: EMPLOYEE PROFILE CARD
# - Each person's information on a separate line
# - A closing border
#
# **Example:** If the person is Alice Johnson, age 28, from San Francisco, a Data Engineer, the output should be:
#
# ```
# ========================================
#           EMPLOYEE PROFILE CARD
# ========================================
# Name: Alice Johnson
# Age: 28
# City: San Francisco
# Job Title: Data Engineer
# ========================================
# ```

# %% [markdown]
# ## Your Code
#
# Below, you will write the code to create this profile card. Use variables to store the person's information, and use `print()` to display the formatted output.

# %%
# Store the person's information in variables
# TODO: Create variables for name, age, city, and job_title
# You can use any person's data you like for testing

# Print the profile card
# TODO: Use print() statements to display the formatted profile card
# Make sure the format matches the expected output exactly

# %% [markdown]
# ## Testing Your Code
#
# When you run this notebook, the grading system will:
# 1. Execute your code
# 2. Check that the printed output matches the expected format
# 3. Test it with different people's data to make sure it works for anyone
#
# Make sure your output has:
# - The correct border (40 equal signs)
# - The title centered with spaces
# - Each field on its own line with the correct label
# - Proper spacing and formatting
