# %% [markdown]
# # Student Grade Manager
#
# ## Problem
#
# You are building a **Student Grade Manager** — a program that helps track and analyze student performance.
#
# Imagine you're a teacher with a class of students. You have their names and grades written down, but you need to:
# - Find out who scored the highest
# - Calculate the class average
# - Organize students by their grades (best to worst)
# - Look up a specific student's grade
# - Add new students as they join
#
# Your program should store student names and grades in lists, perform these operations, and display the results clearly.

# %% [markdown]
# ## Expected Output
#
# **Example 1:** Basic operations on a small class
#
# ```
# Input:
#   names = ["Alice", "Bob", "Charlie"]
#   grades = [85, 92, 78]
#
# Operations:
#   - Highest grade: 92 (Bob)
#   - Average grade: 85.0
#   - Sorted by grade (descending): [("Bob", 92), ("Alice", 85), ("Charlie", 78)]
#   - Find grade of "Alice": 85
# ```
#
# **Example 2:** After adding a new student
#
# ```
# Input:
#   Starting with: names = ["Alice", "Bob"], grades = [85, 92]
#   Add: "Diana" with grade 88
#
# Result:
#   names = ["Alice", "Bob", "Diana"]
#   grades = [85, 92, 88]
#   Average grade: 88.33
#   Sorted by grade (descending): [("Bob", 92), ("Diana", 88), ("Alice", 85)]
# ```
#
# **Example 3:** Edge case — single student
#
# ```
# Input:
#   names = ["Eve"]
#   grades = [95]
#
# Operations:
#   - Highest grade: 95
#   - Average: 95.0
#   - Sorted: [("Eve", 95)]
# ```

# %% [markdown]
# ## Your Task
#
# Implement the following functions to manage student grades. Each function should work with lists of names and grades.

# %%
def get_highest_grade(names, grades):
    """
    Return the highest grade value from the grades list.
    
    Args:
        names: list of student names
        grades: list of student grades
    
    Returns:
        int or float: the maximum grade
    """
    pass

# %%
def get_student_with_highest_grade(names, grades):
    """
    Return the name of the student with the highest grade.
    
    Args:
        names: list of student names
        grades: list of student grades
    
    Returns:
        str: name of the student with the highest grade
    """
    pass

# %%
def calculate_average_grade(names, grades):
    """
    Calculate and return the average grade.
    
    Args:
        names: list of student names
        grades: list of student grades
    
    Returns:
        float: the average grade (rounded to 2 decimal places)
    """
    pass

# %%
def get_student_grade(names, grades, student_name):
    """
    Find and return the grade of a specific student by name.
    
    Args:
        names: list of student names
        grades: list of student grades
        student_name: the name of the student to look up
    
    Returns:
        int or float: the grade of the student, or None if not found
    """
    pass

# %%
def add_student(names, grades, student_name, grade):
    """
    Add a new student and their grade to the lists.
    
    Args:
        names: list of student names (modified in place)
        grades: list of student grades (modified in place)
        student_name: name of the new student
        grade: grade of the new student
    
    Returns:
        None (modifies the lists in place)
    """
    pass

# %%
def sort_students_by_grade(names, grades):
    """
    Return a list of (name, grade) tuples sorted by grade in descending order.
    
    Args:
        names: list of student names
        grades: list of student grades
    
    Returns:
        list of tuples: [(name, grade), ...] sorted by grade (highest first)
    """
    pass

# %% [markdown]
# ## Test Your Implementation
#
# Run the cells below to test your functions with the examples from the problem statement.

# %%
# Test Example 1
names1 = ["Alice", "Bob", "Charlie"]
grades1 = [85, 92, 78]

print("Example 1:")
print(f"Names: {names1}")
print(f"Grades: {grades1}")
print(f"Highest grade: {get_highest_grade(names1, grades1)}")
print(f"Student with highest grade: {get_student_with_highest_grade(names1, grades1)}")
print(f"Average grade: {calculate_average_grade(names1, grades1)}")
print(f"Alice's grade: {get_student_grade(names1, grades1, 'Alice')}")
print(f"Sorted by grade: {sort_students_by_grade(names1, grades1)}")

# %%
# Test Example 2
names2 = ["Alice", "Bob"]
grades2 = [85, 92]

print("\nExample 2 (before adding Diana):")
print(f"Names: {names2}")
print(f"Grades: {grades2}")

add_student(names2, grades2, "Diana", 88)

print("\nAfter adding Diana:")
print(f"Names: {names2}")
print(f"Grades: {grades2}")
print(f"Average grade: {calculate_average_grade(names2, grades2)}")
print(f"Sorted by grade: {sort_students_by_grade(names2, grades2)}")

# %%
# Test Example 3
names3 = ["Eve"]
grades3 = [95]

print("\nExample 3 (single student):")
print(f"Names: {names3}")
print(f"Grades: {grades3}")
print(f"Highest grade: {get_highest_grade(names3, grades3)}")
print(f"Average: {calculate_average_grade(names3, grades3)}")
print(f"Sorted: {sort_students_by_grade(names3, grades3)}")
