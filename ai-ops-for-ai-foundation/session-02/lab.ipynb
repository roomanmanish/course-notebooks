# %% [markdown]
# # Student Grade Calculator
#
# ## The Story
#
# Imagine you're a teacher at the end of a semester. You have a spreadsheet with 30 test scores, and you need to assign each student a letter grade. Doing this by hand would take forever, and you might make mistakes. But with a simple program, you can automate the entire process in seconds.
#
# Your program needs to be smart enough to:
# 1. Accept a numeric score (0–100)
# 2. Map it to the correct letter grade
# 3. Reject invalid scores (negative or above 100) with a clear message
#
# This is where **conditional logic** comes in. Your program will use `if`, `elif`, and `else` statements to make decisions based on the score value.

# %% [markdown]
# ## Grading Scale
#
# - **A**: 90–100
# - **B**: 80–89
# - **C**: 70–79
# - **D**: 60–69
# - **F**: Below 60
#
# **Invalid inputs**: Negative scores or scores > 100 should return `'Invalid score'`

# %% [markdown]
# ## Your Task
#
# Write a function `calculate_grade(score)` that:
# - Takes a numeric score as input
# - Returns the corresponding letter grade (string) based on the scale above
# - Returns `'Invalid score'` if the score is negative or greater than 100
#
# ### Expected Behavior
#
# - `calculate_grade(95)` → `'A'`
# - `calculate_grade(75)` → `'C'`
# - `calculate_grade(-5)` → `'Invalid score'`
# - `calculate_grade(105)` → `'Invalid score'`
# - `calculate_grade(60)` → `'D'`
# - `calculate_grade(89)` → `'B'`

# %%
def calculate_grade(score):
    """
    Accepts a numeric score and returns the corresponding letter grade.
    
    Args:
        score: A numeric value (int or float)
    
    Returns:
        A string: the letter grade ('A', 'B', 'C', 'D', 'F') or 'Invalid score'
    """
    pass

# %% [markdown]
# ## Test Your Function
#
# Run the cell below to test your implementation with a few examples:

# %%
# Test cases (these are NOT the graded tests, just for your own verification)
print('Testing calculate_grade function:')
print(f'Score 95: {calculate_grade(95)}')
print(f'Score 75: {calculate_grade(75)}')
print(f'Score -5: {calculate_grade(-5)}')
print(f'Score 105: {calculate_grade(105)}')
print(f'Score 60: {calculate_grade(60)}')
print(f'Score 89: {calculate_grade(89)}')

# %% [markdown]
# ## Hints (if you get stuck)
#
# - Think about the **order** of your conditions. Should you check for invalid scores first, or the grade ranges?
# - Use **comparison operators** (`<`, `>`, `<=`, `>=`) to check if a score falls within a range.
# - Use **logical operators** (`and`, `or`) to combine multiple conditions if needed.
# - Remember: `if` checks the first condition, `elif` checks additional conditions, and `else` is the fallback.
