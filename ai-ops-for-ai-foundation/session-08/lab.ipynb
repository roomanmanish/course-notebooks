# %% [markdown]
# # Animal Kingdom Class Hierarchy
#
# ## Problem
#
# You are building a class hierarchy to model an animal kingdom. Imagine you're designing a zoo management system where different animals share common behaviors but also have unique characteristics.
#
# **The Story:**
# Every animal in the zoo needs to eat and sleep—these are universal behaviors. But a dog barks, a cat meows, and a bird chirps. Instead of writing the same `eat()` and `sleep()` code three times, you'll create one parent class (`Animal`) that all animals inherit from, then customize each animal's unique sound.
#
# **Your Task:**
# 1. Create an `Animal` parent class with:
#    - An `__init__` method that stores the animal's `name` and `species`
#    - A method `eat()` that returns a string describing the animal eating
#    - A method `sleep()` that returns a string describing the animal sleeping
#
# 2. Create three child classes (`Dog`, `Cat`, `Bird`) that inherit from `Animal` and each override a method called `make_sound()` to return their unique sound.
#
# 3. Create a function `describe_animal(animal)` that takes any animal object and returns a string combining the animal's name, species, and the sound it makes. This demonstrates **polymorphism**—the same function works with any animal type.
#
# 4. Create a function `animal_routine(animal)` that takes an animal, calls its `eat()` and `sleep()` methods, and returns a string describing the full routine. This shows how inherited methods work the same way across all subclasses.
#
# ## Expected Output
#
# **Example 1: Creating and describing a Dog**
# ```
# dog = Dog("Buddy", "Canis familiaris")
# describe_animal(dog)
# # Output: "Buddy the Canis familiaris says: Woof!"
# ```
#
# **Example 2: Creating and describing a Cat**
# ```
# cat = Cat("Whiskers", "Felis catus")
# describe_animal(cat)
# # Output: "Whiskers the Felis catus says: Meow!"
# ```
#
# **Example 3: Animal routine for a Bird**
# ```
# bird = Bird("Tweety", "Passer domesticus")
# animal_routine(bird)
# # Output: "Tweety eats seeds. Tweety sleeps in a nest. Tweety says: Chirp!"
# ```
#
# **Example 4: Polymorphism in action**
# ```
# animals = [Dog("Rex", "Canis familiaris"), Cat("Mittens", "Felis catus"), Bird("Polly", "Psittacus erithacus")]
# for animal in animals:
#     print(describe_animal(animal))
# # Output:
# # Rex the Canis familiaris says: Woof!
# # Mittens the Felis catus says: Meow!
# # Polly the Psittacus erithacus says: Chirp!
# ```

# %%
# Define the Animal parent class and its child classes (Dog, Cat, Bird)
# Implement the describe_animal and animal_routine functions

class Animal:
    pass


class Dog(Animal):
    pass


class Cat(Animal):
    pass


class Bird(Animal):
    pass


def describe_animal(animal):
    pass


def animal_routine(animal):
    pass

# %% [markdown]
# ## Test Your Implementation
#
# Run the cells below to verify your implementation matches the expected output.

# %%
# Test Example 1: Dog
dog = Dog("Buddy", "Canis familiaris")
print(describe_animal(dog))

# %%
# Test Example 2: Cat
cat = Cat("Whiskers", "Felis catus")
print(describe_animal(cat))

# %%
# Test Example 3: Bird routine
bird = Bird("Tweety", "Passer domesticus")
print(animal_routine(bird))

# %%
# Test Example 4: Polymorphism
animals = [Dog("Rex", "Canis familiaris"), Cat("Mittens", "Felis catus"), Bird("Polly", "Psittacus erithacus")]
for animal in animals:
    print(describe_animal(animal))
