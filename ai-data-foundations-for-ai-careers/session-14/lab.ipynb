# %% [markdown]
# Given a realistic loan approval dataset, inspect and clean it, perform EDA with visualizations, flag data quality and bias issues, define features/label, and produce a train/validation/test-ready dataset with a written summary of findings.

# %%
# Write your solution here
