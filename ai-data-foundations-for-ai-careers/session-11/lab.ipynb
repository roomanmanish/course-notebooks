# %% [markdown]
# Choose a prediction goal for the customer dataset, split it into X (features) and y (label), and justify whether it is a classification or regression task.

# %%
# Write your solution here
