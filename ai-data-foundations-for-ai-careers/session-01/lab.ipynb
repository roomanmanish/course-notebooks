# %% [markdown]
# In a guided Jupyter notebook, Run and Observe a simple end-to-end machine learning workflow and understand where data preparation fits into the process.
#
# 1. Load the provided dataset using Pandas.
# 2. Inspect the dataset and identify the input features and target label.
# 3. Prepare the data for the model.
# 4. Run the provided training function.
# 5. Evaluate the model using the provided evaluation function.
# 6. Make a prediction for a new example.
# 7. Identify the stages of the pipeline:
#    Data → Preparation → Training → Evaluation → Prediction
# 8. Write a short explanation of where data preparation is used and why it matters.
#
# The learner is not expected to implement or explain the ML algorithm itself. The purpose of the lab is to observe the workflow and understand the role of data.

# %%
# Write your solution here
