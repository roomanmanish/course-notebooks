# %% [markdown]
# Perform groupby and cross-tab analysis on the cleaned customer dataset to uncover at least three meaningful patterns relevant to predicting customer behavior.

# %%
# Write your solution here
