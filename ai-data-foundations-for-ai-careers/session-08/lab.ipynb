# %% [markdown]
# Create a set of histograms, boxplots, bar charts, and a scatterplot on the customer dataset that visually support the patterns found in the EDA session.

# %%
# Write your solution here
