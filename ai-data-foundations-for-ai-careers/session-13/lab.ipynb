# %% [markdown]
# Given a dataset and a realistic AI use case, inspect the data for representation, fairness, and privacy concerns.
#
# Tasks:
#
# 1. Identify which groups are represented in the dataset.
# 2. Identify any groups that may be underrepresented.
# 3. Identify at least two potential fairness risks.
# 4. Identify any privacy or consent concerns.
# 5. Explain how these issues could affect a future AI system.
# 6. Write two practical recommendations for improving responsible data use.

# %%
# Write your solution here
