# %% [markdown]
# Load a realistic e-commerce customer dataset into Pandas and identify its observations, features, candidate label, and structured/unstructured columns.

# %%
# Write your solution here
