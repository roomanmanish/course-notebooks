# %% [markdown]
# Calculate mean, median, mode, variance, and standard deviation for key numeric features in the customer dataset and write an interpretation of what each reveals.

# %%
# Write your solution here
