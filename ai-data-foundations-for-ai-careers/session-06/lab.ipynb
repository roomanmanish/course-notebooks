# %% [markdown]
# Use IQR and z-score methods to flag outliers in numeric columns and identify at least one potential data leakage or representation bias risk in the cleaned dataset.

# %%
# Write your solution here
