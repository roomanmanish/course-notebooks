# %% [markdown]
# # Build a Tiny Neural Network by Hand
#
# A neural network turns customer behaviour into a prediction (e.g. 'will this customer act?') by passing numbers through weighted sums and activation functions. Below you'll build that pipeline yourself with plain NumPy, then observe how changing the weights shifts the prediction.
#
# The dataset `data.csv` contains browsing behaviour for a set of e-commerce customers.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv("data.csv")
df.head()

# %% [markdown]
# ## Part 1 -- Activation functions
#
# Implement the two activation functions used later in the network. Both must work element-wise on NumPy arrays of any shape.
#
# Expected behaviour:
# - `sigmoid(0)` -> `0.5`
# - `sigmoid` squashes any real number into the open interval `(0, 1)`
# - `relu([-5.0, 0.0, 3.2])` -> `[0.0, 0.0, 3.2]`

# %%
def sigmoid(z):
    raise NotImplementedError


def relu(z):
    raise NotImplementedError

# %% [markdown]
# ## Part 2 -- Forward propagation
#
# Implement a network with one hidden layer (ReLU) and one output layer (Sigmoid):
#
# ```
# hidden = relu(X @ W1 + b1)
# output = sigmoid(hidden @ W2 + b2)
# ```
#
# `forward_pass` must return a tuple `(hidden, output)`.
#
# Toy check: with `X = [[1.0, 2.0], [-1.0, 0.5]]` and the small weight matrices described in the lab instructions, `output` should be approximately `[[0.648], [0.485]]`.

# %%
def forward_pass(X, W1, b1, W2, b2):
    raise NotImplementedError

# %% [markdown]
# ## Part 3 -- Predict action likelihood for real customers
#
# Build the feature matrix from `df` using the columns, in this exact order:
# `time_on_site_min, pages_viewed, past_purchases, cart_value_usd`.
#
# Run it through `forward_pass` and return a 1-D array of probabilities, one per row of `df`, in the same order as the dataframe.

# %%
def predict_action_likelihood(df, W1, b1, W2, b2):
    raise NotImplementedError

# %% [markdown]
# ## Part 4 -- What happens if the weights change?
#
# Given a baseline network (`W1, b1, W2, b2`) and an alternative output-layer weight matrix `W2_alt`, compute predictions for every customer under both weight sets (keeping `W1`, `b1`, `b2` the same) and return both probability arrays as a tuple `(baseline_predictions, alt_predictions)`.

# %%
def compare_weight_effect(df, W1, b1, W2, b2, W2_alt):
    raise NotImplementedError
