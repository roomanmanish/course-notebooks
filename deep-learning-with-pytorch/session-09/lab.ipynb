# %% [markdown]
# You are responding to a “3 a.m. pipeline incident” where a fraud-detection training job is failing in production. Diagnose and fix six deliberately planted defects involving data leakage, incorrect labels, exploding gradients, device mismatch, tensor-shape errors, and an unstable learning rate. For each defect, identify the symptom, root cause, correction, and validation result, then document how the fix restored the pipeline.

# %%
# Write your solution here
