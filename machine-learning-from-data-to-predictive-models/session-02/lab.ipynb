# %% [markdown]
# # Predicting House Prices with Linear Regression
#
# ## Problem
# You are given housing data with numeric features (`area_sqft`, `bedrooms`, `bathrooms`, `age_years`) and a target column `price`.
# Build a Linear Regression pipeline that trains on part of the data, predicts prices for unseen houses, and reports coefficients that can be interpreted in plain language (e.g. price change per extra square foot).

# %% [markdown]
# ## Expected output
# - A trained model whose `.coef_` has one value per feature and whose `.intercept_` is a single number.
# - A dictionary of `{feature_name: coefficient}` you can read as: 'for each extra unit of this feature, price changes by this much'.
# - Evaluation metrics `{'mse': ..., 'r2': ...}` computed on the **test** set (not the training set).
# - A scatter plot of predicted vs actual test prices, with points clustering near the diagonal.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
def load_data(path="data.csv"):
    """Return the housing data as a pandas DataFrame."""
    pass

# %%
def prepare_features(df):
    """Return (X, y): the numeric feature columns and the price column."""
    pass

# %%
def split_data(X, y, test_size=0.2, random_state=42):
    """Return (X_train, X_test, y_train, y_test)."""
    pass

# %%
def train_linear_regression(X_train, y_train):
    """Return a fitted regression model."""
    pass

# %%
def get_predictions(model, X_test):
    """Return predicted values for X_test."""
    pass

# %%
def get_coefficients(model, feature_names):
    """Return a dict mapping each feature name to its learned coefficient."""
    pass

# %%
def evaluate_predictions(y_true, y_pred):
    """Return a dict with keys 'mse' and 'r2' describing prediction quality."""
    pass

# %% [markdown]
# ## Build the full pipeline
# Use the functions above to load the data, split it, train the model, predict, and evaluate.
# Store your final results in the variables below — these are checked automatically.

# %%
df = None
X = None
y = None
X_train, X_test, y_train, y_test = None, None, None, None
model = None
predictions = None
coefficients = None
metrics = None

# %% [markdown]
# ## Visualize predictions
# Produce a scatter plot comparing predicted prices against actual prices for the test set, so you can visually judge how close the model's line-of-best-fit thinking gets to reality.

# %%
# Build your predicted-vs-actual plot here
