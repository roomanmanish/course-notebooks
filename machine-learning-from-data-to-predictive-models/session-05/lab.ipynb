# %% [markdown]
# # Confusion matrix and metric selection for churn prediction
#
# See the lab instructions for the full problem statement and expected output examples.
#
# You will implement three functions:
# 1. `apply_threshold(probabilities, threshold=0.5)`
# 2. `confusion_matrix_counts(y_true, y_pred)`
# 3. `classification_metrics(y_true, y_pred)`
#
# Then use `data.csv` (actual churn outcome + Session 4 model probabilities) to explore how the results change as you move the decision threshold.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('data.csv')
df.head()

# %% [markdown]
# ## Implement the evaluation functions
#
# Fill in the bodies below. Each docstring describes exactly what the function must return.

# %%
def apply_threshold(probabilities, threshold=0.5):
    """
    Convert an iterable of predicted probabilities into hard class labels.

    A probability that is greater than or equal to `threshold` becomes 1,
    otherwise it becomes 0. Return the labels as a list or numpy array of
    ints, in the same order and same length as `probabilities`.
    """
    raise NotImplementedError


def confusion_matrix_counts(y_true, y_pred):
    """
    Compare y_true and y_pred (two equal-length iterables of 0/1 labels) and
    return a dict with integer keys 'tp', 'tn', 'fp', 'fn' counting how many
    predictions fall into each confusion-matrix cell.
    """
    raise NotImplementedError


def classification_metrics(y_true, y_pred):
    """
    Compare y_true and y_pred and return a dict with float keys 'accuracy',
    'precision', 'recall', 'f1'.

    If a metric's denominator would be zero, report 0.0 for that metric
    instead of raising an error.
    """
    raise NotImplementedError

# %% [markdown]
# ## Explore the churn dataset (ungraded, for your own understanding)
#
# Use your three functions on `df['y_true']` and `df['y_pred_proba']`.
# Try at least two different thresholds (for example one stricter and one
# more lenient than 0.5) and compare the confusion matrices and metrics you
# get. Which threshold would you recommend to the business, and why?

# %%
# Your exploration here
