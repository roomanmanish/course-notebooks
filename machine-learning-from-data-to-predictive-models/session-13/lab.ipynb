# %% [markdown]
# # Capstone build: baseline through multi-model training
#
# You are given `data.csv`, a small customer dataset. Your job is to frame this as a supervised learning problem (predict `churn`), build a baseline, prepare the data safely (no leakage), and train several models to compare.
#
# Work through the cells below. Each stub function needs a real implementation before the notebook will run end to end.

# %% [markdown]
# ## Expected output
#
# - `baseline_accuracy`: a number between 0 and 1 (majority-class accuracy).
# - `X_train`, `X_test`, `y_train`, `y_test`: a train/test split with no overlapping rows.
# - `models`: a dict of at least three fitted classifiers, e.g. `{"logistic_regression": ..., "decision_tree": ..., "random_forest": ..., "knn": ...}`.
# - `results`: a dict mapping each model name to its test-set accuracy.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Load the data

# %%
def load_data(path="data.csv"):
    """Load the dataset at `path` into a DataFrame."""
    raise NotImplementedError

# %%
df = load_data("data.csv")
df.head()

# %% [markdown]
# ## Frame the problem: identify features and target

# %%
def get_features_and_target(df):
    """Return (X, y): the feature table and the churn target Series."""
    raise NotImplementedError

# %%
X, y = get_features_and_target(df)

# %% [markdown]
# ## Establish a baseline

# %%
def compute_baseline_accuracy(y):
    """Return the accuracy of always predicting the most frequent class in y."""
    raise NotImplementedError

# %%
baseline_accuracy = compute_baseline_accuracy(y)
baseline_accuracy

# %% [markdown]
# ## Split and prepare data without leakage
#
# Any encoding or scaling must be learned only from the training portion and then applied to the test portion.

# %%
def split_data(X, y, test_size=0.3, random_state=42):
    """Split X, y into X_train, X_test, y_train, y_test."""
    raise NotImplementedError

# %%
X_train, X_test, y_train, y_test = split_data(X, y)

# %%
def preprocess_features(X_train, X_test):
    """Fit any needed preprocessing on X_train only, then transform both
    X_train and X_test. Return (X_train_processed, X_test_processed) with
    no missing values remaining."""
    raise NotImplementedError

# %%
X_train_processed, X_test_processed = preprocess_features(X_train, X_test)

# %% [markdown]
# ## Train multiple models
#
# Train at least three classifiers appropriate for this kind of tabular problem.

# %%
def train_models(X_train, y_train):
    """Train several classifiers on X_train, y_train and return a dict
    mapping a model name to the fitted model object."""
    raise NotImplementedError

# %%
models = train_models(X_train_processed, y_train)
models

# %% [markdown]
# ## Evaluate and record results

# %%
def evaluate_models(models, X_test, y_test):
    """Return a dict mapping each model name to its accuracy on X_test, y_test."""
    raise NotImplementedError

# %%
results = evaluate_models(models, X_test_processed, y_test)
results
