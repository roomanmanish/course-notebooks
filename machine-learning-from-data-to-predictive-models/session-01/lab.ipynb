# %% [markdown]
# # Baseline predictors for two real problems
#
# You have two datasets:
# - `data_housing.csv` (target column `price`) -> a **regression** problem.
# - `data_churn.csv` (target column `churn`) -> a **classification** problem.
#
# For each one: split into train/test, build a naive baseline that ignores every feature, and evaluate that baseline on the *test* set only.
#
# See the lab instructions for concrete input -> output examples.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
def split_train_test(df, test_size=0.2, random_state=42):
    """Return (train_df, test_df) split from df using the given test_size and random_state."""
    pass


def mean_baseline(y_train):
    """Return the single baseline value to predict for every example in a regression problem."""
    pass


def mae(y_true, y_pred):
    """Return the mean absolute error between y_true (array-like) and y_pred (a single number or array-like of matching length)."""
    pass


def majority_class_baseline(y_train):
    """Return the most frequent label found in y_train, to predict for every example in a classification problem."""
    pass


def accuracy(y_true, y_pred):
    """Return the fraction of predictions that match y_true; y_pred may be a single label or array-like of matching length."""
    pass

# %% [markdown]
# ## Apply your functions to the two datasets
#
# Load each CSV, split it, build the appropriate baseline, and evaluate it on the held-out test rows.

# %%
housing_df = pd.read_csv("data_housing.csv")
churn_df = pd.read_csv("data_churn.csv")

housing_target_col = "price"
churn_target_col = "churn"

housing_train, housing_test = split_train_test(housing_df, test_size=0.2, random_state=42)
churn_train, churn_test = split_train_test(churn_df, test_size=0.2, random_state=42)

# Fill these in using the functions defined above.
housing_baseline = None        # baseline predicted price
housing_baseline_mae = None    # error of that baseline on housing_test

churn_baseline = None            # baseline predicted churn label
churn_baseline_accuracy = None   # accuracy of that baseline on churn_test
