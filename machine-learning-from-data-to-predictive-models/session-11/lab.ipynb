# %% [markdown]
# Train plain, Ridge, and Lasso regression models on the housing dataset, compare train/test error and coefficient values to observe overfitting reduction.

# %%
# Write your solution here
