# %% [markdown]
# # Random Forest churn classifier and feature importance
#
# ## Problem
#
# Build a pipeline that trains a single Decision Tree and a Random Forest on the same churn dataset, evaluates both, extracts the forest's feature importances, and compares the two models' metrics side by side.
#
# See the lab README / instructions for the exact expected output format.

# %% [markdown]
# ## Data
#
# The dataset `data.csv` has columns: `customer_id`, `tenure_months`, `monthly_charges`, `total_charges`, `contract_type`, `support_calls`, `churn`.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
def load_data(path="data.csv"):
    """Return the churn dataset at `path` as a pandas DataFrame with its original columns."""
    raise NotImplementedError

# %%
def prepare_features(df):
    """Return (X, y).

    X: a fully numeric DataFrame of predictor columns (tenure_months, monthly_charges,
    total_charges, contract_type, support_calls) with contract_type turned into a
    numeric representation. customer_id and churn must NOT appear in X.

    y: a Series of 0/1 values where churn == 'Yes' maps to 1 and 'No' maps to 0.
    """
    raise NotImplementedError

# %%
def split_data(X, y, test_size=0.3, random_state=42):
    """Return (X_train, X_test, y_train, y_test) split from X, y using the given
    test_size and random_state so the split is reproducible."""
    raise NotImplementedError

# %%
def train_decision_tree(X_train, y_train, random_state=42):
    """Return a Decision Tree classifier fitted on X_train, y_train."""
    raise NotImplementedError


def train_random_forest(X_train, y_train, n_estimators=100, random_state=42):
    """Return a Random Forest classifier with the given n_estimators and random_state,
    fitted on X_train, y_train."""
    raise NotImplementedError

# %%
def evaluate_model(model, X_test, y_test):
    """Return a dict with keys 'accuracy', 'precision', 'recall', 'f1', each a float
    between 0 and 1, computed from model's predictions on X_test versus y_test."""
    raise NotImplementedError

# %%
def get_feature_importances(model, feature_names):
    """Return a pandas Series indexed by feature_names with the model's
    feature_importances_, sorted from largest to smallest importance."""
    raise NotImplementedError

# %%
def compare_models(dt_metrics, rf_metrics):
    """Return a pandas DataFrame with index ['Decision Tree', 'Random Forest'] and
    columns ['accuracy', 'precision', 'recall', 'f1'], filled from dt_metrics and
    rf_metrics (each a dict as produced by evaluate_model)."""
    raise NotImplementedError

# %% [markdown]
# ## Run your pipeline
#
# Use the cell below to call your functions in order, print the comparison table, and
# plot the feature importances (e.g. a horizontal bar chart) so you can see which
# features the Random Forest relies on most.

# %%
# Build and explore your pipeline here.
