# %% [markdown]
# # Predicting Customer Churn with Logistic Regression
#
# ## Problem
#
# `data.csv` contains customer records with `tenure_months`, `monthly_charges`, `support_calls`, `contract_length_months`, and a `churn` label (1 = churned, 0 = stayed).
#
# Your job: train a Logistic Regression model that estimates the **probability** each customer churns, evaluate it, and visualize how a model built on just two features separates churners from non-churners.
#
# ## Expected output
#
# - `sigmoid(0) == 0.5`; `sigmoid` of a large positive number is near 1, of a large negative number is near 0.
# - `predict_probabilities(model, X_test)` returns an array of numbers between 0 and 1 (one per test customer).
# - `predict_labels(model, X_test)` returns an array of 0/1 class predictions.
# - `accuracy` is a single number between 0 and 1 describing how often the model's label predictions matched reality on the held-out test set.
# - A plot of `tenure_months` vs `monthly_charges`, colored by churn, with the two-feature model's decision boundary drawn on top.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Building blocks
#
# Implement each function below. Docstrings describe exactly what each one must return.

# %%
def sigmoid(z):
    """Return the logistic sigmoid of z (scalar or array-like), values in (0, 1)."""
    raise NotImplementedError


def load_data(path="data.csv"):
    """Load the churn dataset from a CSV file and return it as a pandas DataFrame."""
    raise NotImplementedError


def get_features_and_target(df):
    """Return (X, y): X is a DataFrame of the numeric predictor columns,
    y is a Series/array of the churn label (0 or 1)."""
    raise NotImplementedError


def split_data(X, y, test_size=0.25, random_state=42):
    """Split X and y into train/test portions.
    Return (X_train, X_test, y_train, y_test)."""
    raise NotImplementedError


def train_logistic_regression(X_train, y_train):
    """Fit a scikit-learn LogisticRegression model on the training data and return it."""
    raise NotImplementedError


def predict_labels(model, X):
    """Return the model's predicted class labels (0 or 1) for the rows in X."""
    raise NotImplementedError


def predict_probabilities(model, X):
    """Return the model's predicted probability of churn (class 1) for the rows in X."""
    raise NotImplementedError


def compute_accuracy(y_true, y_pred):
    """Return the fraction of predictions in y_pred that match y_true."""
    raise NotImplementedError


def train_two_feature_model(df, feature_x, feature_y, random_state=42):
    """Fit a LogisticRegression model using only the two given feature columns
    (predicting churn). Return (model, X_two, y) where X_two is the two-column
    DataFrame used for training and y is the churn label used for training."""
    raise NotImplementedError


def plot_decision_boundary(model, X_two, y, feature_x, feature_y):
    """Draw a scatter plot of X_two (colored by y) with model's decision boundary
    overlaid, labeled with feature_x and feature_y. Return the matplotlib Figure."""
    raise NotImplementedError

# %% [markdown]
# ## Full pipeline
#
# Use the functions above to build the complete pipeline. Assign your results to the
# variables below (replace `None`) so they can be inspected afterwards.

# %%
df = None
X = None
y = None
X_train = X_test = y_train = y_test = None
model = None
y_pred = None
y_proba = None
accuracy = None

# %% [markdown]
# ## Two-feature decision boundary
#
# Now fit a model on only `tenure_months` and `monthly_charges`, then visualize where
# it draws the line between predicted churners and non-churners.

# %%
boundary_feature_x = "tenure_months"
boundary_feature_y = "monthly_charges"
boundary_model = None
boundary_X = None
boundary_y = None

# %%
# Call plot_decision_boundary(...) here with your fitted boundary_model once ready.
