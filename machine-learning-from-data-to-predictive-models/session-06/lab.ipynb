# %% [markdown]
# # Growing and pruning a Decision Tree classifier
#
# ## Problem
#
# Using `data.csv` (customer tenure, monthly charges, support calls, churn label), build shallow and deep decision trees to predict `churn`, compare their train/test performance, and visualize a tree so its splits can be read as rules.
#
# ## Expected output
#
# - `load_data()` returns a DataFrame with 15 rows and columns `tenure_months, monthly_charges, support_calls, churn`.
# - A tree trained with `max_depth=2` has an actual depth of at most 2.
# - Comparing a shallow tree and a fully-grown tree on the same split should show the fully-grown tree reaching (near) perfect training accuracy, while test accuracy may or may not follow — that gap is the overfitting signal.
# - Feature importances for the three numeric features sum to `1.0`.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load and prepare the data
#
# Implement `load_data` to read `data.csv`, and `get_features_target` to separate the numeric predictors (`tenure_months`, `monthly_charges`, `support_calls`) from the `churn` label.

# %%
def load_data(path="data.csv"):
    raise NotImplementedError


def get_features_target(df):
    raise NotImplementedError

# %% [markdown]
# ### Split and train trees
#
# Implement `split_data` to create train/test sets, and `train_tree` to fit a `DecisionTreeClassifier` that respects a given `max_depth` (use `None` for an unrestricted tree).

# %%
def split_data(X, y, test_size=0.3, random_state=42):
    raise NotImplementedError


def train_tree(X_train, y_train, max_depth=None, random_state=42):
    raise NotImplementedError

# %% [markdown]
# ### Evaluate and interpret
#
# Implement `evaluate_accuracy` (accuracy of a fitted model on any feature/label set), `get_feature_importances` (importances paired with feature names), and `compare_train_test` (a dict with both training and test accuracy for a tree of a given depth, trained on the given split).

# %%
def evaluate_accuracy(model, X, y):
    raise NotImplementedError


def get_feature_importances(model, feature_names):
    raise NotImplementedError


def compare_train_test(X_train, X_test, y_train, y_test, max_depth=None, random_state=42):
    raise NotImplementedError

# %% [markdown]
# ### Explore (not separately graded, but needed for your writeup)
#
# Use the functions above to actually load the data, produce a shallow tree and a deep tree, compare their train/test accuracy, look at feature importances, and render at least one tree with `plot_tree` so you can read its rules. Add a short markdown note summarizing what you observe about overfitting.

# %%
# Your exploration code goes here.
