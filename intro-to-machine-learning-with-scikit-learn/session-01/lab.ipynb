# %% [markdown]
# # Load Iris Dataset and Split into Train-Test Sets
#
# In this lab, you will load the Iris dataset, apply stratified train-test split, and verify class balance.
#
# **Objectives:**
# 1. Load the Iris dataset
# 2. Inspect the data
# 3. Split into train and test sets with stratification
# 4. Verify class distributions
# 5. Visualize the split
# 6. Confirm reproducibility

# %% [markdown]
# ## Cell 1: Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Cell 2: Load the Iris Dataset
#
# **TODO:** Load the Iris dataset using `load_iris()` and create a pandas DataFrame.
# - Use `iris.data` for features and `iris.feature_names` for column names
# - Add a 'target' column with `iris.target`
# - Store the result in a variable called `df`

# %%
# TODO: Load iris dataset and create DataFrame
iris = load_iris()
df = None  # Replace with your code

# Verify
print(f"DataFrame shape: {df.shape}")
print(f"Columns: {df.columns.tolist()}")

# %% [markdown]
# ## Cell 3: Inspect the Data
#
# **TODO:** Display the first 5 rows, total number of rows, and class distribution.

# %%
# TODO: Inspect data
# Print first 5 rows
print("First 5 rows:")
print(None)  # Replace with df.head()

# Print total rows
print(f"\nTotal rows: {None}")  # Replace with len(df)

# Print class distribution
print("\nClass distribution:")
print(None)  # Replace with df['target'].value_counts().sort_index()

# %% [markdown]
# ## Cell 4: Prepare Features and Labels
#
# **TODO:** Separate features (X) and labels (y).
# - X should contain all columns except 'target'
# - y should contain only the 'target' column

# %%
# TODO: Separate features and labels
X = None  # Replace with df.drop('target', axis=1)
y = None  # Replace with df['target']

# Verify
print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")

# %% [markdown]
# ## Cell 5: Stratified Train-Test Split
#
# **TODO:** Use `train_test_split()` with:
# - `test_size=0.2` (80% train, 20% test)
# - `random_state=42` (for reproducibility)
# - `stratify=y` (to balance classes)
#
# Store results in `X_train`, `X_test`, `y_train`, `y_test`.

# %%
# TODO: Perform stratified train-test split
X_train, X_test, y_train, y_test = None  # Replace with train_test_split(...)

# Verify
print(f"X_train shape: {X_train.shape}")
print(f"X_test shape: {X_test.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"y_test shape: {y_test.shape}")

# %% [markdown]
# ## Cell 6: Verify Train Set Distribution
#
# **TODO:** Print the class distribution of the training set using `value_counts().sort_index()`.

# %%
# TODO: Print train set class distribution
print("Train set class distribution:")
print(None)  # Replace with y_train.value_counts().sort_index()

# %% [markdown]
# ## Cell 7: Verify Test Set Distribution
#
# **TODO:** Print the class distribution of the test set using `value_counts().sort_index()`.

# %%
# TODO: Print test set class distribution
print("Test set class distribution:")
print(None)  # Replace with y_test.value_counts().sort_index()

# %% [markdown]
# ## Cell 8: Visualize the Split
#
# **TODO:** Create a side-by-side bar chart comparing class distributions.
# - Use `plt.subplots(1, 2, figsize=(10, 4))`
# - Left plot: Train set distribution
# - Right plot: Test set distribution
# - Use `value_counts().sort_index().plot(kind='bar', ax=axes[i])`

# %%
# TODO: Create visualization
fig, axes = None  # Replace with plt.subplots(1, 2, figsize=(10, 4))

# Plot train set
# TODO: y_train.value_counts().sort_index().plot(kind='bar', ax=axes[0], color='steelblue')
# TODO: axes[0].set_title('Train Set Class Distribution')
# TODO: axes[0].set_ylabel('Count')
# TODO: axes[0].set_xlabel('Class')

# Plot test set
# TODO: y_test.value_counts().sort_index().plot(kind='bar', ax=axes[1], color='coral')
# TODO: axes[1].set_title('Test Set Class Distribution')
# TODO: axes[1].set_ylabel('Count')
# TODO: axes[1].set_xlabel('Class')

# TODO: plt.tight_layout()
# TODO: plt.show()

# %% [markdown]
# ## Cell 9: Verify Reproducibility
#
# **TODO:** Run the split again with the same `random_state=42` and verify that the indices are identical.
# - Store the new split in `X_train_2`, `X_test_2`, `y_train_2`, `y_test_2`
# - Use `assert` to verify that `y_train.index == y_train_2.index` (all elements match)

# %%
# TODO: Perform split again with same random_state
X_train_2, X_test_2, y_train_2, y_test_2 = None  # Replace with train_test_split(...)

# TODO: Verify reproducibility
# assert (y_train.index == y_train_2.index).all(), "Train indices do not match!"
# assert (y_test.index == y_test_2.index).all(), "Test indices do not match!"

print("✓ Reproducibility verified: Same random_state produces identical splits")
