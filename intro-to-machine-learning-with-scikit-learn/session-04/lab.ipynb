# %% [markdown]
# # Build and Evaluate a Linear Regression Model
#
# In this lab, you will train a linear regression model to predict house prices, compute key regression metrics (MSE, RMSE, R²), and create a residual plot to assess model fit.
#
# **Objectives:**
# 1. Load and explore a housing dataset
# 2. Split data into train and test sets
# 3. Train a linear regression model
# 4. Compute MSE, RMSE, and R² on both sets
# 5. Create and interpret a residual plot
# 6. Summarize findings and suggest improvements

# %% [markdown]
# ## Cell 1: Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Set random seed for reproducibility
np.random.seed(42)

# %% [markdown]
# ## Cell 2: Load and Explore Data
#
# **TODO:** Load `data.csv` and display:
# - DataFrame shape
# - First 5 rows
# - Data types and missing values
# - Basic statistics (mean, std, min, max)

# %%
# TODO: Load data from 'data.csv'
df = None  # Replace with pd.read_csv(...)

# TODO: Display shape
print(f"Dataset shape: {df.shape}")

# TODO: Display first few rows
print("\nFirst 5 rows:")
print(df.head())

# TODO: Display info (data types, missing values)
print("\nData info:")
print(df.info())

# TODO: Display statistics
print("\nBasic statistics:")
print(df.describe())

# %% [markdown]
# ## Cell 3: Prepare Features and Target
#
# **TODO:**
# - Identify the target variable (should be 'price')
# - Separate features (X) and target (y)
# - Perform train-test split (80/20, random_state=42)

# %%
# TODO: Define target and features
# Target: 'price' column
# Features: all other columns
y = None  # Replace with df['price']
X = None  # Replace with df.drop('price', axis=1)

print(f"Features shape: {X.shape}")
print(f"Target shape: {y.shape}")
print(f"\nFeature columns: {list(X.columns)}")

# TODO: Split into train (80%) and test (20%)
X_train, X_test, y_train, y_test = None  # Replace with train_test_split(...)

print(f"\nTrain set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")

# %% [markdown]
# ## Cell 4: Train Linear Regression Model
#
# **TODO:**
# - Create a LinearRegression model
# - Fit on training data
# - Make predictions on both train and test sets

# %%
# TODO: Create and fit LinearRegression model
model = None  # Replace with LinearRegression()
# TODO: Fit on training data
# model.fit(...)

# TODO: Make predictions on train and test sets
y_train_pred = None  # Replace with model.predict(X_train)
y_test_pred = None   # Replace with model.predict(X_test)

print("Model trained successfully!")
print(f"Number of features: {model.n_features_in_}")
print(f"Model coefficients shape: {model.coef_.shape}")

# %% [markdown]
# ## Cell 5: Compute Regression Metrics
#
# **TODO:**
# - Calculate MSE for train and test
# - Calculate RMSE for train and test (sqrt of MSE)
# - Calculate R² for train and test
# - Create a summary table or print results clearly

# %%
# TODO: Compute MSE for train and test
mse_train = None  # Replace with mean_squared_error(...)
mse_test = None   # Replace with mean_squared_error(...)

# TODO: Compute RMSE (square root of MSE)
rmse_train = None  # Replace with np.sqrt(mse_train)
rmse_test = None   # Replace with np.sqrt(mse_test)

# TODO: Compute R² for train and test
r2_train = None  # Replace with r2_score(...)
r2_test = None   # Replace with r2_score(...)

# TODO: Create a summary table
metrics_summary = pd.DataFrame({
    'Metric': ['MSE', 'RMSE', 'R²'],
    'Train': [mse_train, rmse_train, r2_train],
    'Test': [mse_test, rmse_test, r2_test]
})

print("\n" + "="*50)
print("REGRESSION METRICS SUMMARY")
print("="*50)
print(metrics_summary.to_string(index=False))
print("="*50)

# %% [markdown]
# ## Cell 6: Create Residual Plot
#
# **TODO:**
# - Calculate residuals for test set (actual - predicted)
# - Create scatter plot: predicted values (x) vs. residuals (y)
# - Add horizontal line at y=0
# - Add labels, title, and grid
# - Interpret the plot below

# %%
# TODO: Calculate residuals for test set
residuals_test = None  # Replace with y_test - y_test_pred

# TODO: Create residual plot
plt.figure(figsize=(10, 6))

# TODO: Scatter plot of predicted vs. residuals
# plt.scatter(...)

# TODO: Add horizontal line at y=0
# plt.axhline(...)

# TODO: Add labels and title
# plt.xlabel(...)
# plt.ylabel(...)
# plt.title(...)
# plt.grid(...)

plt.tight_layout()
plt.show()

print(f"\nResiduals statistics:")
print(f"Mean: {np.mean(residuals_test):.4f}")
print(f"Std Dev: {np.std(residuals_test):.4f}")
print(f"Min: {np.min(residuals_test):.4f}")
print(f"Max: {np.max(residuals_test):.4f}")

# %% [markdown]
# ## Cell 7: Interpretation and Summary
#
# **TODO:** Write a 3–5 sentence summary addressing:
# 1. Does the model fit well? (Reference R² and RMSE)
# 2. Is there overfitting or underfitting? (Compare train vs. test metrics)
# 3. What does the residual plot reveal?
# 4. What are potential next steps for improvement?

# %% [markdown]
# **TODO: Write your interpretation here.**
#
# Replace this text with your analysis:
#
# - **Model Fit:** [Describe R² values and RMSE. Does the model explain variance well?]
# - **Overfitting/Underfitting:** [Compare train vs. test metrics. Is there a large gap?]
# - **Residual Plot:** [Describe the pattern. Are residuals random? Any systematic bias?]
# - **Next Steps:** [What could improve the model? More features? Non-linear model? Feature engineering?]
