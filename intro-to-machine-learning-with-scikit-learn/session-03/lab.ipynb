# %% [markdown]
# # Evaluate Iris Classifier with Confusion Matrix and Metrics
#
# In this lab, you will train a classifier on the Iris dataset and evaluate it using accuracy, confusion matrix, precision, recall, and F1-score.
#
# ## Learning Objectives
# - Calculate accuracy and understand its limitations
# - Build and visualize a confusion matrix
# - Compute precision, recall, and F1-score for each class
# - Interpret classification metrics and identify class confusions

# %% [markdown]
# ## Step 1: Import Libraries and Load Data
#
# Import necessary libraries and load the Iris dataset.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    confusion_matrix,
    classification_report,
    precision_score,
    recall_score,
    f1_score
)

# TODO: Load the Iris dataset
# iris = load_iris()
# X = iris.data
# y = iris.target
# target_names = iris.target_names

print("Dataset loaded. Shape:", X.shape)
print("Classes:", target_names)

# %% [markdown]
# ## Step 2: Split Data and Train Classifier
#
# Split the data into training and test sets (80/20), then train a LogisticRegression classifier.

# %%
# TODO: Split the data into train and test sets
# Use train_test_split with test_size=0.2 and random_state=42
# X_train, X_test, y_train, y_test = ...

# TODO: Train a LogisticRegression classifier
# clf = LogisticRegression(random_state=42, max_iter=200)
# clf.fit(X_train, y_train)

# TODO: Make predictions on the test set
# y_pred = clf.predict(X_test)

print(f"Training set size: {X_train.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
print(f"Predictions shape: {y_pred.shape}")

# %% [markdown]
# ## Step 3: Calculate Accuracy
#
# Compute the accuracy of the classifier on the test set.

# %%
# TODO: Calculate accuracy using accuracy_score
# accuracy = accuracy_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Accuracy (%): {accuracy * 100:.2f}%")

# %% [markdown]
# ## Step 4: Build and Visualize Confusion Matrix
#
# Compute the confusion matrix and visualize it as a heatmap.

# %%
# TODO: Compute the confusion matrix
# cm = confusion_matrix(y_test, y_pred)

print("Confusion Matrix:")
print(cm)
print()

# TODO: Visualize the confusion matrix using seaborn heatmap
# - Create a figure with figsize=(8, 6)
# - Use sns.heatmap with annot=True, fmt='d', cmap='Blues'
# - Set x-axis label to 'Predicted' and y-axis label to 'Actual'
# - Set title to 'Confusion Matrix'
# - Set x and y tick labels to target_names

# plt.figure(figsize=(8, 6))
# sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
#             xticklabels=target_names,
#             yticklabels=target_names)
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
# plt.title('Confusion Matrix')
# plt.tight_layout()
# plt.show()

print("Confusion matrix visualization complete.")

# %% [markdown]
# ## Step 5: Generate Classification Report
#
# Compute precision, recall, and F1-score for each class.

# %%
# TODO: Generate the classification report
# report = classification_report(y_test, y_pred, target_names=target_names)

print("Classification Report:")
print(report)

# %% [markdown]
# ## Step 6: Detailed Metrics per Class
#
# Compute precision, recall, and F1-score for each class individually.

# %%
# TODO: Compute precision, recall, and F1-score for each class
# Use precision_score, recall_score, and f1_score with average=None
# This returns an array with one value per class

# precision_per_class = precision_score(y_test, y_pred, average=None)
# recall_per_class = recall_score(y_test, y_pred, average=None)
# f1_per_class = f1_score(y_test, y_pred, average=None)

print("\nMetrics per Class:")
print("-" * 60)
for i, class_name in enumerate(target_names):
    print(f"{class_name}:")
    print(f"  Precision: {precision_per_class[i]:.4f}")
    print(f"  Recall:    {recall_per_class[i]:.4f}")
    print(f"  F1-score:  {f1_per_class[i]:.4f}")
    print()

# %% [markdown]
# ## Step 7: Interpretation and Analysis
#
# Write a brief analysis of the results. Address the following questions:
#
# 1. **Which class is easiest/hardest to classify?** (Look at precision and recall)
# 2. **Are there any confusions between specific classes?** (Look at the confusion matrix)
# 3. **Why is accuracy alone insufficient for this dataset?** (Consider class balance and error types)
# 4. **What do precision and recall tell us about each class?**
#
# Write your analysis in the cell below.

# %% [markdown]
# # TODO: Write your interpretation here
#
# ## Analysis
#
# ### Easiest/Hardest Classes
# - [Analyze which classes have the highest/lowest precision and recall]
#
# ### Class Confusions
# - [Identify which classes are confused with each other in the confusion matrix]
#
# ### Why Accuracy Alone is Insufficient
# - [Explain why accuracy can be misleading, especially for imbalanced datasets]
#
# ### Precision vs. Recall
# - [Discuss the trade-off between precision and recall for each class]
